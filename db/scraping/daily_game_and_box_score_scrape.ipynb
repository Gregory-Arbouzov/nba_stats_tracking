# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
import numpy as np
import os

import re
import io

import psycopg2
from psycopg2.extensions import register_adapter, AsIs
register_adapter(np.int64, AsIs)
#from config import config
from configparser import ConfigParser

# %%
# url for all games played on date - https://www.basketball-reference.com/boxscores/?month=3&day=15&year=2024
# url for box score of specific game - https://www.basketball-reference.com/boxscores/202403150CHO.html

# Which info do we need?
# 1. How many games played
# 2. Final Score for each
# 3. Winner / Loser for each

# %%
games_on_date_test_url = 'https://www.basketball-reference.com/boxscores/?month=3&day=15&year=2024'

games_on_date_test_page = requests.get(games_on_date_test_url,params={
      'render_js': True})    

game_on_date_test_soup = BeautifulSoup(games_on_date_test_page.text, 'lxml')

# %%
game_on_date_test_soup.find_all('tr')[0].find('a', href=re.compile('/boxscores/'))
# Out:
# <a href="/boxscores/202403150CHO.html">F<span class="no_mobile">inal</span></a>

# %%
game_on_date_test_soup.find_all('tr', {'class':['winner', 'loser']})[0].find('a', href=re.compile('/boxscores/'))
# Out:
# <a href="/boxscores/202403150CHO.html">F<span class="no_mobile">inal</span></a>

# %%
for i in range(len(game_on_date_test_soup.find_all('tr', {'class':['winner', 'loser']}))):
    try:
        print(game_on_date_test_soup.find_all('tr', {'class':['winner', 'loser']})[i].find('a', href=re.compile('/boxscores/')).attrs['href'].split('/')[2].split('.')[0][-3:])
    except:
        pass
# Out:
# CHO
# DET
# NOP
# SAS
# TOR
# UTA

# %%
print(game_on_date_test_soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/bbr/deploy/www" data-version="klecko-" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
# <link href="https://cdn.ssref.net/req/202501061" rel="dns-prefetch"/>
# <script>
# /* https://docs.osano.com/hc/en-us/articles/22469433444372-Google-Consent-Mode-v2  */
#   window.dataLayer = window.dataLayer ||[];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('consent','default',{
#         'ad_storage':'denied',
#         'analytics_storage':'denied',
#         'ad_user_data':'denied',
#         'ad_personalization':'denied',
#         'personalization_storage':'denied',
#         'functionality_storage':'granted',
#         'security_storage':'granted',
#         'wait_for_update': 500
#       });
#       gtag("set", "ads_data_redaction", true);
# </script>
# <script src="https://cmp.osano.com/16CGnCU8UtNhM14sg/12669873-8cf8-41e2-be1f-1cb803cbffe0/osano.js"></script>
# <style>.osano-cm-widget{display: none;}</style>
# <title>NBA Games Played on March 15, 2024 | Basketball-Reference.com</title>
# <meta content="Get the list of all the NBA games played on March 15, 2024 and more on Basketball-Reference.com" name="Description"/>
# <link href="https://www.basketball-reference.com/boxscores/" rel="canonical"/>
# <!-- include:start ="/inc/klecko_header_bbr.html_f" -->
# <!-- no:cookie fast load the css.           -->
# <script>function gup(n) {n = n.replace(/[\[]/, '\\[').replace(/[\]]/, '\\]'); var r = new RegExp('[\\?&]'+n+'=([^&#]*)'); var re = r.exec(location.search);   return re === null?'':decodeURIComponent(re[1].replace(/\+/g,' '));}; document.srdev = gup('srdev')</script>
# <script>if (!document.srdev && (location.hostname === 'sup.fb.srdevel.com')) { document.srdev = 'aw'; }/* sf: hardcode this in for sup.fb.srdevel.com for testing purposes. */</script>
# <link crossorigin="" href="https://cdn.ssref.net" rel="preconnect"/>
# <link crossorigin="" href="https://www.google-analytics.com" rel="preconnect"/>
# <link crossorigin="" href="https://www.googletagservices.com" rel="preconnect"/>
# <link as="script" crossorigin="" href="https://cdn.ssref.net/req/202501061/js/bbr/sr-min.js" rel="preload"/>
# <link as="fetch" crossorigin="" href="https://cdn.ssref.net/req/202501061/icons/sr_icons-min.svg?bbr" rel="preload"/>
# <link as="fetch" crossorigin="" href="https://www.basketball-reference.com/short/inc/main_nav_menu.json" rel="preload"/>
# <link as="image" crossorigin="" href="https://cdn.ssref.net/req/201604190/images/chosen-sprite.png" rel="preload"/>
# <link as="style" crossorigin="" href="https://cdn.ssref.net/req/202501061/css/bbr/sr-min.css" rel="preload"/>
# <!-- CSS start -->
# <style>html,body{margin:0;padding:0;font:14px/1.25 "Helvetica Neue",helvetica,arial,sans-serif;color:#000}@media(prefers-reduced-motion:no-preference){html:not(.backstop){scroll-behavior:smooth}}@media(prefers-reduced-motion:reduce){html{scroll-behavior:auto!important}*{animation:none!important;transition-duration:0s!important}}html:not(.backstop) div,html:not(.backstop) span{scroll-margin:2.5em 0 0 0;scroll-snap-margin:2.5em 0 0 0}body{position:relative;background:#c9cbcd;z-index:0;-webkit-text-size-adjust:none;-moz-text-size-adjust:none;-ms-text-size-adjust:none}a img{border:0}ul,li,ol{margin:0;padding:0;list-style-type:none}table th,table td{border:0}iframe{max-width:100%}code{background:#eee}a,button,input,select,textarea,label,summary{touch-action:manipulation;-ms-touch-action:manipulation}::selection{background:#ff0;text-shadow:none}html.no-js .hasmore,html.no-js .js,html.js .no-js,html.no-js button,html.is_build .hide_build,html.is_dev .hide_dev,html.is_live .hide_live{display:none!important}.js-select{visibility:hidden}a[href]{color:#34d}a[href]:visited{color:#848}a[href]:hover{color:#5e44b3}a[href]:active{color:#b12}a[href^="tel:"]::before{content:"\260E";display:inline-block;margin-right:0}a[href^="mailto:"]::before{content:"\2709";display:inline-block;margin-right:0}.icon_group a[href^="tel:"]:before,.icon_group a[href^="mailto:"]:before{content:""}.screen_only{display:initial}.user_logged_in .not_logged_in,.logged_in,.sr_cpi_control,.print_only{display:none}#perflog,#modernizr,.user_logged_in .logged_in{display:block}h2{color:#000;margin-bottom:5px;font-size:1.5em}img.right{float:right;margin:0 0 5px 5px}img.left{float:left;margin:0 15px 15px 0}sup{font-size:.75em;position:relative;top:-0.4em;vertical-align:baseline}#wrap{width:100%;background:#fff;position:relative}#wrap>div,#wrap>ul{width:100%;position:relative;clear:both}.hidden-iso,.hidden,#content .hidden,.gutterad,.more,.print_only,#warnings.hide,#nag_devs{display:none}#inner_nav.hidden{visibility:hidden}.float_wrap{overflow:hidden}.grid2{display:grid;grid-column-gap:10px;grid-template-columns:1fr 1fr}.grid2 img{max-width:100%}.grid2.heavyleft{grid-template-columns:2fr 1fr}.grid2.heavyright{grid-template-columns:1fr 2fr}#header{overflow:visible;background:#efeeed;border-bottom:3px solid #f8951d;min-height:50px}#header img{height:25px;float:left;padding:8px 0 8px 2%;max-width:71%;max-width:calc(95% - 80px)}#header #nav_trigger{display:block;cursor:pointer;float:right;padding:7px 2% 7px 1%;height:30px}#header #nav_trigger a{color:#8f5400;font-size:20px;font-weight:bold;text-decoration:none;display:inline-block}#header #nav_trigger a:before{color:#8f5400;content:"\2630 ";font-weight:normal}#header #nav{display:none;clear:both;width:88%;background:#fff;padding:7px 6% 0;border-bottom:3px solid #8f5400;border-top:3px solid #8f5400;overflow:hidden;font-size:12px}#header #nav .usertools{font-weight:bold;font-size:12px;margin:0 0 4px;padding:7px 6% 0;border-top:1px solid #c9cbcd}#header #nav .breadcrumbs{font-size:12px;padding:7px 6%;border-top:1px solid #c9cbcd}#header #nav_trigger.open{background:#8f5400}#header #nav_trigger.open a{color:#fff}#header #nav_trigger.open a:before{color:#fff}#header #nav.open{display:block}#header .social{margin:15px 0;display:none}#header.open_search{margin-bottom:50px}#header #subnav{display:none}#translations{background-color:#ffa;padding:4px 0;text-align:center;display:none}#translations.show{display:block}#translations .closer{top:4px}#translations .langs{display:inline-block}#translations .links{margin:0 35px 0 0}#translations .links>div{display:inline-block}#translations .links .welcome{font-weight:bold}#header .search{margin-top:10px;clear:both;padding:0 2% 6px}#header .search input,#header .search input:active,#header .search input:focus{height:32px;font-size:20px}.search input[type="search"]{padding:4px 5px;border:#747678 1px solid;width:73%;margin-right:2%}.search input[type="search"].prefilled{background-color:#ffa}.search i ...
# <link crossorigin="" href="https://cdn.ssref.net/req/202501061/css/bbr/sr-min.css" media="print" onload="if (document.srdev) { this.href = 'https://cdn.ssref.net/nocdn/dev/'.concat(document.srdev.substr(0,2),'/css/bbr/sr.css'); }; this.media='all'" rel="stylesheet"/>
# <noscript><link href="https://cdn.ssref.net/req/202501061/css/bbr/sr-min.css" rel="stylesheet" type="text/css"/></noscript>
# <!-- CSS END -->
# <!-- JS START -->
# <script class="allowed">var sr_is_production = true;
# function vjs_getUrlParameter(e){e=e.replace(/[\[]/,"\\[").replace(/[\]]/,"\\]");e=new RegExp("[\\?&]"+e+"=([^&#]*)").exec(location.search);return null===e?"":decodeURIComponent(e[1].replace(/\+/g," "))}document.lang="","/es/"===window.location.pathname.substr(0,4)?document.lang="es":"/pt/"===window.location.pathname.substr(0,4)?document.lang="pt":"/fr/"===window.location.pathname.substr(0,4)?document.lang="fr":"/it/"===window.location.pathname.substr(0,4)?document.lang="it":"/de/"===window.location.pathname.substr(0,4)?document.lang="de":(window.location.pathname.substr(0,4),document.lang="en"),vjs_getUrlParameter("lang")&&(document.lang=vjs_getUrlParameter("lang")),document.srdev=null,vjs_getUrlParameter("srdev")?document.srdev=vjs_getUrlParameter("srdev"):"sup"===window.location.host.substr(0,3)&&(document.srdev="aw");var el,log_performance=!0,is_new_jscss_version=!1,sr_detect_operaMini=-1<navigator.userAgent.indexOf("Opera Mini"),sr_detect_firefox=(sr_detect_operaMini&&((el=document.querySelector("html")).className=el.className.concat(" operamini")),-1<navigator.userAgent.indexOf("Firefox")),sr_detect_firefoxMobile=(sr_detect_firefox&&((el=document.querySelector("html")).className=el.className.concat(" firefox")),-1<navigator.userAgent.indexOf("Firefox")&&(-1<navigator.userAgent.indexOf("Mobile")||-1<navigator.userAgent.indexOf("Tablet"))),sr_detect_ie=(sr_detect_firefoxMobile&&((el=document.querySelector("html")).className=el.className.concat(" firefox-mobile")),(()=>{var e=window.navigator.userAgent;if(0<e.indexOf("Trident/7.0"))return 11;if(0<e.indexOf("Trident/6.0"))return 10;if(0<e.indexOf("Trident/5.0"))return 9;for(var t=3,n=document.createElement("div"),r=n.getElementsByTagName("i");n.innerHTML="\x3c!--[if gt IE "+ ++t+"]><i></i><![endif]--\x3e",r[0];);return 4<t&&t})()),sr_detect_edge=!sr_detect_ie&&!!window.StyleMedia,sr_detect_safari=/Safari/.test(navigator.userAgent)&&/Apple Computer/.test(navigator.vendor),className="no-js",patt=((el=document.querySelector("html")).classList?el.classList.remove(className):el.className=el.className.replace(new RegExp("(^|\\b)"+className.split(" ").join("|")+"(\\b|$)","gi")," "),el.className=el.className.concat(" js"),!function(a,d,S){function E(e,t){return typeof e===t}function T(e){return"function"!=typeof d.createElement?d.createElement(e):m?d.createElementNS.call(d,"http://www.w3.org/2000/svg",e):d.createElement.apply(d,arguments)}function R(e,t,n,r){var o,i,a,s,l="modernizr",c=T("div");(s=d.body)||((s=T(m?"svg":"body")).fake=!0);if(parseInt(n,10))for(;n--;)(i=T("div")).id=r?r[n]:l+(n+1),c.appendChild(i);return(o=T("style")).type="text/css",o.id="s"+l,(s.fake?s:c).appendChild(o),s.appendChild(c),o.styleSheet?o.styleSheet.cssText=e:o.appendChild(d.createTextNode(e)),c.id=l,s.fake&&(s.style.background="",s.style.overflow="hidden",a=u.style.overflow,u.style.overflow="hidden",u.appendChild(s)),o=t(c,e),s.fake?(s.parentNode.removeChild(s),u.style.overflow=a,u.offsetHeight):c.parentNode.removeChild(c),!!o}function U(e){return e.replace(/([a-z])-([a-z])/g,function(e,t,n){return t+n.toUpperCase()}).replace(/^-/,"")}function D(e){return e.replace(/([A-Z])/g,function(e,t){return"-"+t.toLowerCase()}).replace(/^ms-/,"-ms-")}function q(e,t){var n=e.length;if("CSS"in a&&"supports"in a.CSS){for(;n--;)if(a.CSS.supports(D(e[n]),t))return!0;return!1}if("CSSSupportsRule"in a){for(var r=[];n--;)r.push("("+D(e[n])+":"+t+")");return R("@supports ("+(r=r.join(" or "))+") { #modernizr { position: absolute; } }",function(e){return"absolute"==(e=e,t=null,n="position","getComputedStyle"in a?(r=getComputedStyle.call(a,e,t),o=a.console,null!==r?n&&(r=r.getPropertyValue(n)):o&&o[o.error?"error":"log"].call(o,"getComputedStyle returning null, its possible modernizr test results are inaccurate")):r=!t&&e.currentStyle&&e.currentStyle[n],r);var t,n,r,o})}return S}function r(e,t,n,r,o){var i,a,s=e.charAt(0).toUpperCase()+e.slice(1),l=(e+" "+re.join(s+" ")+s).split(" ");if(E(t,"string")||void 0===t){var c=l,d=t ...
# </script>
# <script>
# let server = (document.srdev) ? 'https://cdn.ssref.net/nocdn/dev/' + document.srdev.substring(0, 2) : "https://cdn.ssref.net/req/202501061";
# let _sr_modern_url = server
# 	+ "/js/bbr"
# 	+ "/sr"+ ((document.srdev) ? "" : "-min")   	+ ".js"
# ;
# loadJS( _sr_modern_url, function() { vjs_ready(sr_fire_js); });
# </script>
# <!-- JS END -->
# <!-- include:end ="/inc/klecko_header_bbr.html_f" -->
# <script>sr_utilities_js_loader.push(function() { vjs_createCookie('srcssfull', 'yes', 0.5 )});</script>
# <meta content="15:26:03 08-Jan-2025" name="revised"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="/home/bbr/deploy/www/boxscores/index.fcgi" name="generated-by"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="no" name="apple-mobile-web-app-capable"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="#4d4438" name="theme-color"/>
# <meta content="#4d4438" name="msapplication-navbutton-color"/>
# <meta content="#4d4438" name="apple-mobile-web-app-status-bar-style"/>
# <!-- HeaderSeoSocial -->
# <meta content="box scores, NBA, ABA" name="keywords"/>
# <meta content="https://www.basketball-reference.com" itemprop="url"/>
# <meta content="Basketball Reference" itemprop="name"/>
# <meta content="BkRef" itemprop="alternateName"/>
# <meta content="" property="fb:app_id"/>
# <meta content="https://www.basketball-reference.com/boxscores/" property="og:url"/>
# <meta content="NBA Games Played on March 15, 2024 | Basketball-Reference.com" property="og:title"/>
# <meta content="Basketball-Reference.com" property="og:site_name"/>
# <meta content="    article" property="og:type"/>
# <meta content="Get the list of all the NBA games played on March 15, 2024 and more on Basketball-Reference.com" property="og:description"/>
# <meta content="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-228x228-precomposed.png" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@bball_ref" name="twitter:site"/>
# <meta content="@bball_ref" name="twitter:creator"/>
# <meta content="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-228x228-precomposed.png" property="twitter:image"/>
# <meta content="Basketball-Reference.com" name="twitter:domain"/>
# <meta content="unsafe-url" name="referrer"/>
# <!-- HeaderSeoSocial:END -->
# <!-- tiles, touch, favicons -->
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-180x180-precomposed.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/favicon-48.png" rel="icon" sizes="48x48"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-228x228-precomposed.png" rel="shortcut icon" sizes="228x228"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-228x228-precomposed.png" rel="apple-touch-icon" sizes="228x228"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-195x195-precomposed.png" rel="apple-touch-icon" sizes="195x195"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-180x180-precomposed.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-128x128-precomposed.png" rel="apple-touch-icon" sizes="128x128"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/apple-touch-icon-57x57-precomposed.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://cdn.ssref.net/req/202501061/favicons/bbr/favicon-32.png" rel="icon" sizes="32x32"/>
# <!--[if IE]>
#     <link rel="shortcut icon"                                href="https://cdn.ssref.net/req/202501061/favicons/bbr/favicon.ico"><![endif]-->
# <meta content="#905500" name="msapplication-TileColor"/>
# <meta content="https://cdn.ssref.net/req/202501061/favicons/bbr/ms-tile-144.png" name="msapplication-TileImage"/>
# <link href="https://cdn.ssref.net/req/202501061/opensearch/opensearch-bbr.xml" rel="search" title=" Player and Team Search" type="application/opensearchdescription+xml"/>
# <!-- tiles, touch, favicons:end -->
# <!-- ad code: begin -->
# <link crossorigin="" href="https://a.pub.network/" rel="preconnect"/>
# <link crossorigin="" href="https://b.pub.network/" rel="preconnect"/>
# <link crossorigin="" href="https://c.pub.network/" rel="preconnect"/>
# <link crossorigin="" href="https://d.pub.network/" rel="preconnect"/>
# <link crossorigin="" href="https://c.amazon-adsystem.com" rel="preconnect"/>
# <link crossorigin="" href="https://s.amazon-adsystem.com" rel="preconnect"/>
# <link crossorigin="" href="https://btloader.com/" rel="preconnect"/>
# <link crossorigin="" href="https://api.btloader.com/" rel="preconnect"/>
# <link crossorigin="" href="https://confiant-integrations.global.ssl.fastly.net" rel="preconnect"/>
# <link href="https://a.pub.network/basketball-reference/cls.css" rel="stylesheet"/>
# <script data-cfasync="false" type="text/javascript">
#   var freestar = freestar || {};
#   freestar.queue = freestar.queue || [];
#   freestar.config = freestar.config || {};
#   freestar.config.enabled_slots = [];
#   freestar.initCallback = function () { (freestar.config.enabled_slots.length === 0) ? freestar.initCallbackCalled = false : freestar.newAdSlots(freestar.config.enabled_slots) }
# </script>
# <script async="" data-cfasync="false" src="https://a.pub.network/basketball-reference/pubfig.min.js"></script>
# <!-- ad code:end -->
# </head>
# <body class="bbr">
# <div id="wrap">
# <div id="header" role="banner">
# <ul class="notranslate" id="subnav">
# <li><a href="https://www.sports-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav"><svg height="15px" width="20px"><use xlink:href="#ic-sr-pennant"></use></svg> Sports Reference ®</a></li>
# <li><a href="https://www.baseball-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Baseball</a></li>
# <li><a href="https://www.pro-football-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Football</a> <a href="https://www.sports-reference.com/cfb/">(college)</a></li>
# <li class="current"><a href="https://www.basketball-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Basketball</a> <a href="https://www.sports-reference.com/cbb/">(college)</a></li>
# <li><a href="https://www.hockey-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Hockey</a></li>
# <li><a href="https://fbref.com/es/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Fútbol</a></li>
# <li><a href="https://www.sports-reference.com/blog/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Blog</a></li>
# <li><a href="https://stathead.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Stathead ®</a></li>
# <li><a href="https://www.immaculategrid.com/basketball/mens/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Immaculate Grid ®</a></li>
# <li><a href="https://www.sports-reference.com/feedback/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav">Questions or Comments?</a></li>
# <li class="user logged_in">Welcome <span class="username"></span> · <a href="https://stathead.com/profile/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav_account">Your Account</a></li>
# <li class="user logged_in"><a class="logout" href="https://stathead.com/users/logout.cgi" onclick="sr_auth_logout_page_elements();if(!this.href.match('redirect_uri')){this.href += '?redirect_uri='+escape(document.location.href)}">Logout</a></li>
# <li class="user not_logged_in"><a class="login" href="https://stathead.com/users/login.cgi?token=1" onclick="if(!this.href.match('redirect_uri')){this.href += '&amp;redirect_uri='+escape(document.location.href)}">Ad-Free Login</a></li>
# <li class="user not_logged_in"><a href="https://stathead.com/users/signup.cgi">Create Account</a></li>
# </ul>
# <a href="/"><img alt="Basketball-Reference.com Logo &amp; Link to home page" onerror="this.src='https://cdn.ssref.net/req/202501061/logos/bbr-logo.png'; this.onerror = null;" src="https://cdn.ssref.net/req/202501061/logos/bbr-logo.svg"/></a>
# <div id="nav_trigger" role="button"><a href="#site_menu_link">MENU</a></div>
# <div aria-label="Basketball-Reference.com sections" id="nav" role="navigation">
# <ul class="hoversmooth nohover" id="main_nav"><li id="header_players"><a href="/players/">Players</a></li>
# <li id="header_teams"><a href="/teams/">Teams</a></li>
# <li id="header_leagues"><a href="/leagues/">Seasons</a></li>
# <li id="header_leaders"><a href="/leaders/">Leaders</a></li>
# <li class="current" id="header_scores"><a href="/boxscores/">Scores</a></li>
# <li class="" id="header_wnba"><a href="/wnba/">WNBA</a></li>
# <li class="" id="header_draft"><a href="/draft/">Draft</a></li>
# <li class="" id="header_stathead"><a href="https://stathead.com/sport/basketball/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_topnav_stathead&amp;utm_content=lnk_top" rel="noopener" target="_blank">Stathead</a></li>
# <li class="" id="header_newsletter"><a href="https://www.basketball-reference.com/email/" rel="noopener" target="_blank">Newsletter</a></li>
# <li><a class="opener" data-scroll="" href="#site_menu_link">Full Site Menu Below</a></li>
# </ul>
# <div class="breadcrumbs">You are here: <div class="crumbs" itemscope="" itemtype="https://schema.org/BreadcrumbList"><span itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem"><a href="/" itemprop="item"><span itemprop="name">BBR Home Page</span></a> <meta content="1" itemprop="position"/></span> &gt; <span itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem"><a href="/boxscores/" itemprop="item"><span itemprop="name">Box Scores</span></a> <meta content="2" itemprop="position"/></span> &gt; <strong>NBA Games Played on March 15, 2024</strong></div></div>
# <ul class="usertools bullets-inline"><li class="user logged_in">Welcome <span class="username"></span> · <a href="https://stathead.com/profile/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav_account">Your Account</a></li>
# <li class="user logged_in"><a class="logout" href="https://stathead.com/users/logout.cgi" onclick="sr_auth_logout_page_elements();if(!this.href.match('redirect_uri')){this.href += '?redirect_uri='+escape(document.location.href)}">Logout</a></li>
# <li class="user not_logged_in"><a class="login" href="https://stathead.com/users/login.cgi?token=1" onclick="if(!this.href.match('redirect_uri')){this.href += '&amp;redirect_uri='+escape(document.location.href)}">Ad-Free Login</a></li>
# <li class="user not_logged_in"><a href="https://stathead.com/users/signup.cgi">Create Account</a></li>
# </ul><!-- ul.user -->
# </div><!-- div#nav -->
# <script>
# function sr_menus_setupMainNav_button_inline () {
#     if (sr_detect_operaMini || !("classList" in document.createElement("_"))) {
# 	return false;
#     }
#     var nav_trigger = document.getElementById('nav_trigger');
#     if(!nav_trigger || nav_trigger.triggered) {
# 	return false;
#     }
#     nav_trigger.triggered = true;
#     var nav = document.getElementById('nav');
#     var nav_trigger_a = nav_trigger.querySelector('a');
#     if (nav_trigger_a) {
# 	nav_trigger_a.setAttribute('href','javascript:void(0)');
# 	nav_trigger.onclick = function (event) {
# 	    nav.classList.toggle('open');
# 	    var is_open = nav.classList.contains('open');
# 	    if (is_open) {
# 		nav_trigger.classList.add('open');
# 	    }
# 	    else {
# 		nav_trigger.classList.remove('open');
# 	    }
# 	    event.preventDefault();
# 	    try { sr_record_analytics_event('MainNavButtonClick_inline',sr_record_directory(),sr_record_page());}
# 	    catch(err) {}
# 	};
#     }
#     return true;
# }
# sr_menus_setupMainNav_button_inline();
# </script><div aria-label="Site Search for players, teams and sections" class="search" role="search">
# <form action="/search/search.fcgi" method="get" name="f_big">
# <div class="ac-outline">
# <div class="ac-wrapper"><input aria-label="Search suggestions based on user search input" autocapitalize="off" autocomplete="off" autocorrect="off" class="ac-hint" dir="auto" name="hint" placeholder="" spellcheck="false" tabindex="-1" type="search"/>
# <input aria-label="Enter a player, team or section name" autocapitalize="off" autocomplete="off" autocorrect="off" class="ac-input completely" dir="auto" name="search" placeholder="Enter Person, Team, Section, etc" spellcheck="false" tabindex="1" type="search"/>
# <div class="ac-dropdown"></div>
# </div>
# </div>
# <input tabindex="2" type="submit" value="Search"/>
# <input data-search-id="" name="pid" type="hidden" value=""/>
# <input data-search-idx="" name="idx" type="hidden" value=""/>
# </form>
# </div><!-- div.search -->
# </div><!-- div#header -->
# <style>
#   .site_announcement {
#     background-color: #fffea6;
#     text-align: center;
#     padding: .4em 0;
#     width: 100%;
#   }
#   .site_announcement div {
#     margin: 0 .3em;
#   }
#   .site_announcement span {
#     white-space: nowrap;
#   }
#   @media only screen and (max-width: 1000px) {
#     .site_annoucement_extra {
#       display: none;
#     }
#   }
#   </style>
# <!-- no announcement -->
# <div id="srcom">
# <!-- fs_728_atf_second -->
# <div class="adblock">
# <!-- div#fs_fs_728_atf_second  -->
# <div align="center" data-freestar-ad="__728x90" id="div-gpt-ad-728x90-ATF">
# <script data-cfasync="false" type="text/javascript">
#     if (sr_detect_ie || sr_detect_edge || Modernizr.adfree) {
#     }
#     else {
#         console.log('push ad:div-gpt-ad-728x90-ATF');
#         freestar.config.enabled_slots.push({ placementName: "div-gpt-ad-728x90-ATF", slotId: "div-gpt-ad-728x90-ATF" });
#     }
#   </script>
# </div>
# <!-- /div.#fs_fs_728_atf_second -->
# </div>
# </div><div class="index" id="content" role="main">
# <h1>NBA Games Played on March 15, 2024</h1>
# <div class="prevnext">
# <a class="button2 prev" href="/boxscores/?month=3&amp;day=14&amp;year=2024">Mar 14, 2024</a>
# <span class="button2 index">Mar 15, 2024</span>
# <a class="button2 next" href="/boxscores/?month=3&amp;day=16&amp;year=2024">Mar 16, 2024</a>
# </div>
# <form action="" class="srbasic" method="get">
# <div class="fieldset linear">
# <div class="formfield">
# <select class="no_chosen" id="month" name="month" size="1">
# <option value="1">January
# </option><option value="2">February
# </option><option selected="" value="3">March
# </option><option value="4">April
# </option><option value="5">May
# </option><option value="6">June
# </option><option value="7">July
# </option><option value="8">August
# </option><option value="9">September
# </option><option value="10">October
# </option><option value="11">November
# </option><option value="12">December
# </option></select>
# </div>
# <div class="formfield">
# <select class="no_chosen" id="day" name="day" size="1">
# <option value="1">1
# </option><option value="2">2
# </option><option value="3">3
# </option><option value="4">4
# </option><option value="5">5
# </option><option value="6">6
# </option><option value="7">7
# </option><option value="8">8
# </option><option value="9">9
# </option><option value="10">10
# </option><option value="11">11
# </option><option value="12">12
# </option><option value="13">13
# </option><option value="14">14
# </option><option selected="" value="15">15
# </option><option value="16">16
# </option><option value="17">17
# </option><option value="18">18
# </option><option value="19">19
# </option><option value="20">20
# </option><option value="21">21
# </option><option value="22">22
# </option><option value="23">23
# </option><option value="24">24
# </option><option value="25">25
# </option><option value="26">26
# </option><option value="27">27
# </option><option value="28">28
# </option><option value="29">29
# </option><option value="30">30
# </option><option value="31">31
# </option></select>
# </div>
# <div class="formfield">
# <select class="no_chosen" id="year" name="year" size="1">
# <option value="1946">1946
# </option><option value="1947">1947
# </option><option value="1948">1948
# </option><option value="1949">1949
# </option><option value="1950">1950
# </option><option value="1951">1951
# </option><option value="1952">1952
# </option><option value="1953">1953
# </option><option value="1954">1954
# </option><option value="1955">1955
# </option><option value="1956">1956
# </option><option value="1957">1957
# </option><option value="1958">1958
# </option><option value="1959">1959
# </option><option value="1960">1960
# </option><option value="1961">1961
# </option><option value="1962">1962
# </option><option value="1963">1963
# </option><option value="1964">1964
# </option><option value="1965">1965
# </option><option value="1966">1966
# </option><option value="1967">1967
# </option><option value="1968">1968
# </option><option value="1969">1969
# </option><option value="1970">1970
# </option><option value="1971">1971
# </option><option value="1972">1972
# </option><option value="1973">1973
# </option><option value="1974">1974
# </option><option value="1975">1975
# </option><option value="1976">1976
# </option><option value="1977">1977
# </option><option value="1978">1978
# </option><option value="1979">1979
# </option><option value="1980">1980
# </option><option value="1981">1981
# </option><option value="1982">1982
# </option><option value="1983">1983
# </option><option value="1984">1984
# </option><option value="1985">1985
# </option><option value="1986">1986
# </option><option value="1987">1987
# </option><option value="1988">1988
# </option><option value="1989">1989
# </option><option value="1990">1990

# </ul>
# </div>
# </div>
# <div class="table_container" id="div_confs_standings_E">
# <table class="suppress_all sortable stats_table" data-cols-to-freeze=",1" id="confs_standings_E">
# <caption>Conference Standings Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
# <tr>
# <th aria-label="Eastern Conference" class="poptip sort_default_asc left" data-stat="team_name" scope="col">Eastern Conference</th>
# <th aria-label="Wins" class="poptip right" data-stat="wins" data-tip="Wins" scope="col">W</th>
# <th aria-label="Losses" class="poptip right" data-stat="losses" data-tip="Losses" scope="col">L</th>
# <th aria-label="Win-Loss Percentage" class="poptip right" data-stat="win_loss_pct" data-tip="Win-Loss Percentage" scope="col">W/L%</th>
# <th aria-label="GB" class="poptip sort_default_asc right" data-stat="gb" data-tip="Games Behind" scope="col">GB</th>
# <th aria-label="Points Per Game" class="poptip right" data-stat="pts_per_g" data-tip="Points Per Game" scope="col">PS/G</th>
# <th aria-label="Opponent Points Per Game" class="poptip right" data-stat="opp_pts_per_g" data-tip="Opponent Points Per Game" scope="col">PA/G</th>
# </tr>
# </thead>
# <tbody><tr class="full_table"><th class="left" csk="0.212" data-stat="team_name" scope="row"><a href="/teams/BOS/2024.html">Boston Celtics</a>*</th><td class="right" data-stat="wins">52</td><td class="right" data-stat="losses">14</td><td class="right" data-stat="win_loss_pct">.788</td><td class="right" data-stat="gb">—</td><td class="right" data-stat="pts_per_g">120.9</td><td class="right" data-stat="opp_pts_per_g">109.7</td></tr>
# <tr class="full_table"><th class="left" csk="0.358" data-stat="team_name" scope="row"><a href="/teams/MIL/2024.html">Milwaukee Bucks</a>*</th><td class="right" data-stat="wins">43</td><td class="right" data-stat="losses">24</td><td class="right" data-stat="win_loss_pct">.642</td><td class="right" data-stat="gb">9.5</td><td class="right" data-stat="pts_per_g">120.4</td><td class="right" data-stat="opp_pts_per_g">117.1</td></tr>
# <tr class="full_table"><th class="left" csk="0.364" data-stat="team_name" scope="row"><a href="/teams/CLE/2024.html">Cleveland Cavaliers</a>*</th><td class="right" data-stat="wins">42</td><td class="right" data-stat="losses">24</td><td class="right" data-stat="win_loss_pct">.636</td><td class="right" data-stat="gb">10.0</td><td class="right" data-stat="pts_per_g">113.8</td><td class="right" data-stat="opp_pts_per_g">109.4</td></tr>
# <tr class="full_table"><th class="left" csk="0.409" data-stat="team_name" scope="row"><a href="/teams/NYK/2024.html">New York Knicks</a>*</th><td class="right" data-stat="wins">39</td><td class="right" data-stat="losses">27</td><td class="right" data-stat="win_loss_pct">.591</td><td class="right" data-stat="gb">13.0</td><td class="right" data-stat="pts_per_g">112.2</td><td class="right" data-stat="opp_pts_per_g">108.1</td></tr>
# <tr class="full_table"><th class="left" csk="0.418" data-stat="team_name" scope="row"><a href="/teams/ORL/2024.html">Orlando Magic</a>*</th><td class="right" data-stat="wins">39</td><td class="right" data-stat="losses">28</td><td class="right" data-stat="win_loss_pct">.582</td><td class="right" data-stat="gb">13.5</td><td class="right" data-stat="pts_per_g">110.7</td><td class="right" data-stat="opp_pts_per_g">109.2</td></tr>
# <tr class="full_table"><th class="left" csk="0.448" data-stat="team_name" scope="row"><a href="/teams/IND/2024.html">Indiana Pacers</a>*</th><td class="right" data-stat="wins">37</td><td class="right" data-stat="losses">30</td><td class="right" data-stat="win_loss_pct">.552</td><td class="right" data-stat="gb">15.5</td><td class="right" data-stat="pts_per_g">123.1</td><td class="right" data-stat="opp_pts_per_g">121.4</td></tr>
# <tr class="full_table"><th class="left" csk="0.455" data-stat="team_name" scope="row"><a href="/teams/MIA/2024.html">Miami Heat</a>*</th><td class="right" data-stat="wins">36</td><td class="right" data-stat="losses">30</td><td class="right" data-stat="win_loss_pct">.545</td><td class="right" data-stat="gb">16.0</td><td class="right" data-stat="pts_per_g">110.1</td><td class="right" data-stat="opp_pts_per_g">109.6</td></tr>
# <tr class="full_table"><th class="left" csk="0.455" data-stat="team_name" scope="row"><a href="/teams/PHI/2024.html">Philadelphia 76ers</a>*</th><td class="right" data-stat="wins">36</td><td class="right" data-stat="losses">30</td><td class="right" data-stat="win_loss_pct">.545</td><td class="right" data-stat="gb">16.0</td><td class="right" data-stat="pts_per_g">115.2</td><td class="right" data-stat="opp_pts_per_g">112.9</td></tr>
# <tr class="full_table"><th class="left" csk="0.522" data-stat="team_name" scope="row"><a href="/teams/CHI/2024.html">Chicago Bulls</a></th><td class="right" data-stat="wins">32</td><td class="right" data-stat="losses">35</td><td class="right" data-stat="win_loss_pct">.478</td><td class="right" data-stat="gb">20.5</td><td class="right" data-stat="pts_per_g">111.8</td><td class="right" data-stat="opp_pts_per_g">113.9</td></tr>
# <tr class="full_table"><th class="left" csk="0.561" data-stat="team_name" scope="row"><a href="/teams/ATL/2024.html">Atlanta Hawks</a></th><td class="right" data-stat="wins">29</td><td class="right" data-stat="losses">37</td><td class="right" data-stat="win_loss_pct">.439</td><td class="right" data-stat="gb">23.0</td><td class="right" data-stat="pts_per_g">119.4</td><td class="right" data-stat="opp_pts_per_g">121.3</td></tr>
# <tr class="full_table"><th class="left" csk="0.606" data-stat="team_name" scope="row"><a href="/teams/BRK/2024.html">Brooklyn Nets</a></th><td class="right" data-stat="wins">26</td><td class="right" data-stat="losses">40</td><td class="right" data-stat="win_loss_pct">.394</td><td class="right" data-stat="gb">26.0</td><td class="right" data-stat="pts_per_g">111.8</td><td class="right" data-stat="opp_pts_per_g">113.9</td></tr>
# <tr class="full_table"><th class="left" csk="0.657" data-stat="team_name" scope="row"><a href="/teams/TOR/2024.html">Toronto Raptors</a></th><td class="right" data-stat="wins">23</td><td class="right" data-stat="losses">44</td><td class="right" data-stat="win_loss_pct">.343</td><td class="right" data-stat="gb">29.5</td><td class="right" data-stat="pts_per_g">113.9</td><td class="right" data-stat="opp_pts_per_g">118.1</td></tr>
# <tr class="full_table"><th class="left" csk="0.746" data-stat="team_name" scope="row"><a href="/teams/CHO/2024.html">Charlotte Hornets</a></th><td class="right" data-stat="wins">17</td><td class="right" data-stat="losses">50</td><td class="right" data-stat="win_loss_pct">.254</td><td class="right" data-stat="gb">35.5</td><td class="right" data-stat="pts_per_g">106.9</td><td class="right" data-stat="opp_pts_per_g">116.8</td></tr>
# <tr class="full_table"><th class="left" csk="0.818" data-stat="team_name" scope="row"><a href="/teams/DET/2024.html">Detroit Pistons</a></th><td class="right" data-stat="wins">12</td><td class="right" data-stat="losses">54</td><td class="right" data-stat="win_loss_pct">.182</td><td class="right" data-stat="gb">40.0</td><td class="right" data-stat="pts_per_g">112.1</td><td class="right" data-stat="opp_pts_per_g">120.3</td></tr>
# <tr class="full_table"><th class="left" csk="0.833" data-stat="team_name" scope="row"><a href="/teams/WAS/2024.html">Washington Wizards</a></th><td class="right" data-stat="wins">11</td><td class="right" data-stat="losses">55</td><td class="right" data-stat="win_loss_pct">.167</td><td class="right" data-stat="gb">41.0</td><td class="right" data-stat="pts_per_g">114.2</td><td class="right" data-stat="opp_pts_per_g">123.9</td></tr>
# </tbody></table>
# </div>
# </div>
# </div>
# </td>
# <td><div>
# <div class="table_wrapper" id="all_confs_standings_W">
# <div class="section_heading assoc_confs_standings_W" id="confs_standings_W_sh">
# <span class="section_anchor" data-label=" " data-no-inpage="1" id="confs_standings_W_link"></span><h2> </h2>
# <div class="section_heading_text">
# <ul><li> </li>
# </ul>
# </div>
# </div>
# <div class="table_container" id="div_confs_standings_W">
# ...
#       <a href="/friv/milestones.fcgi">Milestone Watch</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/executives/NBA_stats.html">Executives</a>
# <div>
# <a href="/executives/moreyda99x.html">Daryl Morey</a>,
#       <a href="/executives/ujirima99x.html">Masai Ujiri</a>,
#       <a href="/executives/rileypa01x.html">Pat Riley</a>,
#       <a href="/executives/aingeda01x.html">Danny Ainge</a>,
#       <a href="/executives/horstjo01x.html">Jon Horst</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/referees/">Referees</a>
# <div>
# <a href="/referees/fortejo99r.html">Joe Forte</a>,
#       <a href="/referees/brothto99r.html">Tony Brothers</a>,
#       <a href="/referees/crawfda99r.html">Dan Crawford</a>,
#       <a href="/referees/olesiro99r.html">Ron Olesiak</a>,
#       <a href="/referees/jonesda99r.html">David Jones</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/gleague/">G League Stats</a>
# <div>
# <a href="/gleague/players/">Players</a>,
#       <a href="/gleague/teams/">Teams</a>,
#       <a href="/gleague/years/">Seasons</a>,
#       <a href="/gleague/leaders/">Leaders</a>,
#       <a href="/gleague/awards/">Awards</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/international/">International Basketball Stats</a>
# <div>
# <a href="/international/players/">Players</a>,
#       <a href="/international/teams/">Teams</a>,
#       <a href="/international/years/">Seasons</a>,
#       <a href="/international/leaders/">Leaders</a>,
#       <a href="/international/awards/">Awards</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/wnba/">WNBA</a>
# <div>
# <a href="/wnba/players/">Players</a>,
#       <a href="/wnba/teams/">Teams</a>,
#       <a href="/wnba/years/">Seasons</a>,
#       <a href="/wnba/leaders/">Leaders</a>,
#       <a href="/wnba/awards/">Awards</a>,
#       <a href="/wnba/allstar/">All-Star Games</a>,
#       <a href="/wnba/executives/">Executives</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/nbl/">NBL</a>
# <div>
# <a href="/nbl/players/">Players</a>,
#       <a href="/nbl/teams/">Teams</a>,
#       <a href="/nbl/years/">Seasons</a>,
#       <a href="/nbl/leaders/">Leaders</a>,
#       <a href="/nbl/awards/">Awards</a>
#       ...
#     </div>
# </li>
# <li>
# <a href="/about/">About</a>
# <div>
# <a href="/about/glossary.html">Glossary</a>,
#       <a href="/about/contact.html">Contact and Media Information</a>,
#       <a href="/about/nba-basketball-faqs.html">Frequently Asked Questions about the NBA, WNBA and Basketball</a>
#       ...
#     </div>
# </li>
# <li><a href="https://www.immaculategrid.com/basketball/mens/?utm_campaign=2023_07_lnk_home_footer_ig&amp;utm_source=bbr&amp;utm_medium=sr_xsite">Immaculate Grid (Men's)</a> and <a href="https://www.immaculategrid.com/basketball/womens/?utm_campaign=2023_07_lnk_home_footer_ig&amp;utm_source=bbr&amp;utm_medium=sr_xsite">Immaculate Grid (Women's)</a>
# <div>Put your basketball knowledge to the test with our daily basketball trivia games. Can you complete the grids?</div>
# </li>
# </ul>
# <ul>
# <li></li>
# <li><a href="https://www.basketball-reference.com/bbr-blog/">Basketball-Reference.com Blog and Articles</a></li>
# </ul></div><!-- div#site_menu -->
# <div>
# <div class="icon_group noload" id="social">
# <div class="section_heading assoc_" id="_sh">
# <span class="section_anchor" data-label="We're Social...for Statheads" data-no-inpage="1" id="_link"></span><h2>We're Social...for Statheads</h2>
# </div>
# <a aria-label="Telephone" class="poptip" data-label="Telephone" data-tip="Call us on Telephone" href="tel://888-512-8907"><svg class="icon phone"><use xlink:href="#ic-phone"></use></svg></a>
# <a aria-label="Our Blog" class="poptip" data-label="Our Blog" data-tip="The Sports Reference Blog" href="//www.sports-reference.com/blog/"><svg class="icon wordpress"><use xlink:href="#ic-wordpress"></use></svg></a>
# <a aria-label="RSS Feed" class="poptip" data-label="RSS Feed" data-tip="Our Blog's RSS Feed" href="https://www.sports-reference.com/blog/feed/"><svg class="icon rss"><use xlink:href="#ic-rss"></use></svg></a>
# <a aria-label="Facebook" class="poptip" data-label="Facebook" data-tip="Basketball-Reference.com at Facebook" href="https://www.facebook.com/Basketball.Reference"><svg class="icon facebook"><use xlink:href="#ic-facebook"></use></svg></a>
# <a aria-label="Twitter" class="poptip" data-label="Twitter" data-tip="Basketball-Reference.com at Twitter" href="https://twitter.com/bball_ref"><svg class="icon twitter"><use xlink:href="#ic-twitter"></use></svg></a>
# <a aria-label="Instagram" class="poptip" data-label="Instagram" data-tip="Basketball-Reference.com at Instagram" href="https://instagram.com/basketball.reference"><svg class="icon instagram"><use xlink:href="#ic-instagram"></use></svg></a>
# <a aria-label="TikTok" class="poptip" data-label="TikTok" data-tip="Basketball-Reference.com at TikTok" href="https://www.tiktok.com/@basketball.reference"><svg class="icon tiktok"><use xlink:href="#ic-tiktok"></use></svg></a>
# <a aria-label="Reddit/r/SR" class="poptip" data-label="Reddit/r/SR" data-tip="Reddit/r/SportsReference" href="https://reddit.com/r/SportsReference"><svg class="icon reddit"><use xlink:href="#ic-reddit"></use></svg></a>
# <a aria-label="YouTube" class="poptip" data-label="YouTube" data-tip="YouTube/SportsReference" href="https://www.youtube.com/user/sportsreference"><svg class="icon youtube"><use xlink:href="#ic-youtube"></use></svg></a>
# <a aria-label="LinkedIn" class="poptip" data-label="LinkedIn" data-tip="Follow SR on LinkedIn" href="https://www.linkedin.com/company/sports-reference-llc"><svg class="icon linkedin"><use xlink:href="#ic-linkedin"></use></svg></a>
# <a aria-label="PayPal" class="poptip" data-label="PayPal" data-tip="Send us money via PayPal" href="https://www.paypal.me/sportsref"><svg class="icon paypal"><use xlink:href="#ic-paypal"></use></svg></a>
# <a aria-label="Threads" class="poptip" data-label="Threads" data-tip="Basketball-Reference.com at Threads" href="https://threads.net/@basketball.reference"><svg class="icon threads"><use xlink:href="#ic-threads"></use></svg></a>
# <p>Every <a href="https://www.sports-reference.com/blog/sports-reference-social-media/">Sports Reference Social Media Account</a></p>
# <p><strong>Site Last Updated:</strong> Wednesday, January  8,  7:29AM
# </p>
# <p><a class="button" href="https://www.sports-reference.com/feedback/" style="display: block">Question, Comment, Feedback, or Correction?</a></p>
# <p><a class="button" href="https://www.basketball-reference.com/email" style="display: block">Subscribe to our Free Email Newsletter</a></p>
# <p><a class="button alt" href="https://stathead.com/sport/basketball/?utm_medium=sr_xsite&amp;utm_source=bbr&amp;utm_campaign=2023_01_footerbttn_stathead" style="background-color:#7e3e89; color: #fff;">Subscribe to Stathead Basketball: Get your first month FREE<br/><em>Your All-Access Ticket to the Basketball Reference Database</em></a></p>
# <p><a href="https://www.sports-reference.com/blog/ways-sports-reference-can-help-your-website/?utm_medium=sr&amp;utm_source=bbr&amp;utm_campaign=site-footer-ways-help">Do you have a sports website? Or write about sports? We have tools and resources that can help you use sports data.  Find out more.</a></p>
# </div><!-- div#social -->
# <div id="tips_tricks">
# <div class="section_heading assoc_tips" id="tips_sh">
# <span class="section_anchor" data-label="FAQs, Tip &amp; Tricks" data-no-inpage="1" id="tips_link"></span><h2>FAQs, Tip &amp; Tricks</h2>
# </div>
# <ul>
# <!-- no Local/FooterTipsTricks.tt2 -->
# <li><a href="//www.sports-reference.com/blog/category/tips-and-tricks/">Tips and Tricks from our Blog.</a></li>
# <li><a href="/linker/">Do you have a blog? Join our linker program.</a></li>
# <li><a href="https://www.sports-reference.com/blog/category/stathead-tutorial-series/">Watch our How-To Videos to Become a Stathead</a></li>
# <li><a href="//stathead.com/?ref=bbr">Subscribe to Stathead and get access to more data than you can imagine</a></li>
# </ul>
# </div><!-- div#tips_tricks -->
# <div id="credits">
# <p>All logos are the trademark &amp; property of their owners and not Sports Reference LLC.  We present them here for purely educational purposes.
# 				<a href="https://www.sports-reference.com/blog/2016/06/redesign-team-and-league-logos-courtesy-sportslogos-net/">Our reasoning for presenting offensive logos.</a></p>
# <p>
#
# 					Logos were compiled by the amazing <a href="http://sportslogos.net/">SportsLogos.net.</a>
# </p>
# <div class="notice">
# <p>Data Provided By
# 	<a href="https://www.sportradar.com/" rel="nofollow"><img alt="SportRadar" border="0" src="https://cdn.ssref.net/req/202501061/images/klecko/sportradar.png" style="background-color:#666; padding:.5em; border-radius:.25em" width="275"/></a>
# 	the official stats partner of the NBA, NHL and MLB.</p>
# </div>
# <p>Copyright © 2000-2025 <a href="//www.sports-reference.com/">Sports Reference LLC</a>. All rights reserved.</p>
# <p>The SPORTS REFERENCE, STATHEAD, IMMACULATE GRID, and IMMACULATE FOOTY trademarks are owned exclusively by Sports Reference LLC. Use without license or authorization is expressly prohibited.
#
# 			</p></div><!-- div#credits -->
# </div>
# </div>
# <ul class="notranslate bullets-inline" id="site_dirs">
# <li><a href="https://www.sports-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav_footer"><svg height="15px" width="20px"><use xlink:href="#ic-sr-pennant"></use></svg> Sports Reference ®</a></li>
# <li><a href="https://www.baseball-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav_footer">Baseball</a></li>
# <li><a href="https://www.pro-football-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav_footer">Football</a> <a href="https://www.sports-reference.com/cfb/">(college)</a></li>
# <li class="current"><a href="https://www.basketball-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav_footer">Basketball</a> <a href="https://www.sports-reference.com/cbb/">(college)</a></li>
# <li><a href="https://www.hockey-reference.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav_footer">Hockey</a></li>
# <li><a href="https://fbref.com/es/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav_footer">Fútbol</a></li>
# <li><a href="https://www.sports-reference.com/blog/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav_footer">Blog</a></li>
# <li><a href="https://stathead.com/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav_footer">Stathead ®</a></li>
# <li><a href="https://www.immaculategrid.com/basketball/mens/?utm_source=bbr&amp;utm_medium=sr_xsite&amp;utm_campaign=2023_01_srnav_footer">Immaculate Grid ®</a></li>
# </ul>
# <div id="about">
# <a href="//www.sports-reference.com/about.html">About</a> •
#   <a href="//www.sports-reference.com/termsofuse.html">Conditions &amp; Terms of Service</a> •
#   <a href="//www.sports-reference.com/advertise.html">Advertise With Us</a>
#  •
#   <a href="//www.sports-reference.com/jobs.html">Jobs at SR</a>
#  •
#   <a href="https://sportsreference.threadless.com/">Basketball-Reference.com T-Shirts &amp; Store</a>
#  •
#   <a href="#" onclick="Osano.cm.showDrawer('osano-cm-dom-info-dialog-open')">Cookie Preferences</a>
# <br/><br/>
# Sports Reference Purpose: We will be the trusted source of information and tools that inspire and empower users to enjoy, understand, and share the sports they love.
#   <br/><br/>
# <a href="//www.sports-reference.com/privacy.html">Privacy Policy</a> •
#   <a href="//www.sports-reference.com/gambling-revenue-policy.html">Gambling Revenue Policy</a> •
#   <a href="//www.sports-reference.com/accessibility-policy.html">Accessibility Policy</a> •
#   <a href="//www.sports-reference.com/data_use.html">Use of Data</a>
# </div>
# <!-- div#about -->
# </div><!-- div#footer -->
# <!-- div#wrap -->
# <!-- yes sticky url:  https://www.basketball-reference.com/boxscores/ -->
# <div id="fs-select-footer"></div>
# <!-- rails -->
# <div class="adblock rails left"><!-- div#fs_fs_rails_left  -->
# <div align="center" data-freestar-ad="" id="div-gpt-ad-160x600-1">
# <script data-cfasync="false" type="text/javascript">
#     if (sr_detect_ie || sr_detect_edge || Modernizr.adfree) {
#     }
#     else {
#         console.log('push ad:div-gpt-ad-160x600-1');
#         freestar.config.enabled_slots.push({ placementName: "div-gpt-ad-160x600-1", slotId: "div-gpt-ad-160x600-1" });
#     }
#   </script>
# </div>
# <!-- /div.#fs_fs_rails_left -->
# </div>
# <div class="adblock rails right"><!-- div#fs_fs_rails_right  -->
# <div align="center" data-freestar-ad="" id="div-gpt-ad-160x600-2">
# <script data-cfasync="false" type="text/javascript">
#     if (sr_detect_ie || sr_detect_edge || Modernizr.adfree) {
#     }
#     else {
#         console.log('push ad:div-gpt-ad-160x600-2');
#         freestar.config.enabled_slots.push({ placementName: "div-gpt-ad-160x600-2", slotId: "div-gpt-ad-160x600-2" });
#     }
#   </script>
# </div>
# <!-- /div.#fs_fs_rails_right -->
# </div>
# <!-- sr_gender is used in Templates/Assets/GoogleAnalytics.tt2 -->
# <script>var sr_gender = "";</script>
# <!-- Google Analytics -->
# <!-- Google Analytics UA,  UA-1890630-2 -->
# <!-- Google Analytics GA4, G-NR1HN85GXQ -->
# <!-- Google Tag Manager --> <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-MC36NL2');</script> <!-- End Google Tag Manager --> <!-- Google Tag Manager (noscript) --> <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MC36NL2" style="display:none;visibility:hidden" width="0"></iframe></noscript> <!-- End Google Tag Manager (noscript) -->
# <script> var sr_cookie = vjs_readCookie('stathead_user') || ''; var sr_cookie_split = sr_cookie.split("::"); var sr_session_key = (sr_cookie_split.length > 1)?sr_cookie_split[2]:''; var sr_ad_free_key = "4"; var sr_site_id = "bbr"; var sr_is_subscriber = (sr_ad_free_key && sr_session_key.vjs_isMatch(new RegExp(sr_ad_free_key + "$"))) || sr_session_key.vjs_isMatch(/1$/) || (sr_site_id === 'stathead' && sr_session_key.vjs_isMatch(/[0-7]$/)); var sr_is_user = sr_cookie !== null && sr_cookie !== ''; var sr_seen_modal = vjs_readCookie('modal_ad') !== null; var sr_device = 'unk'; if (Modernizr.phone) { sr_device = 'phone'; } else if (Modernizr.tablet) { sr_device = 'tablet'; } else if (Modernizr.laptop) { sr_device = 'laptop'; } else if (Modernizr.desktop) { sr_device = 'desktop'; } var sr_stathead_site = vjs_readCookie('stathead_site') || ''; var sr_stathead_type = vjs_readCookie('stathead_type') || ''; window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); /* GA4: individual site code config, do not send a page view (double counts) */ gtag('config', 'G-NR1HN85GXQ', { 'is_sub': sr_is_subscriber, 'is_user': sr_is_user, 'page_gender': typeof(sr_gender) === 'string'? sr_gender: null, 'stathead_type': sr_stathead_type, 'stathead_site': sr_stathead_site, 'viewport_width': Modernizr.viewport_width, send_page_view: false }); /* GA4: all sr sites together */ /* I believe linker works as a parameter here, although there didn\'t seem to be a simple "true" value to set besides this one --NW https://developers.google.com/analytics/devguides/collection/gtagjs/cross-domain Add configs for both sets of code. */ gtag('config', 'G-80FRT7VJ60', { 'linker': { 'domains' : ['stathead.com'] }, 'is_sub': sr_is_subscriber, 'is_user': sr_is_user, 'page_gender': typeof(sr_gender) === 'string'? sr_gender: null, 'stathead_type': sr_stathead_type, 'stathead_site': sr_stathead_site, 'viewport_width': Modernizr.viewport_width }); </script>
# <!-- End Google Analytics -->
# <!-- Start of HubSpot Embed Code -->
# <script async="" defer="" id="hs-script-loader" src="//js.hs-scripts.com/20503178.js" type="text/javascript"></script>
# <!-- End of HubSpot Embed Code -->
# </td></tr></div></div></div></body>
# <!-- SR -->
# </html>

# %%
game_on_date_test_soup.find_all('a', href=re.compile('/boxscores/'))
# Out:
# [<a href="/boxscores/">Scores</a>,
#  <a href="/boxscores/" itemprop="item"><span itemprop="name">Box Scores</span></a>,
#  <a class="button2 prev" href="/boxscores/?month=3&amp;day=14&amp;year=2024">Mar 14, 2024</a>,
#  <a class="button2 next" href="/boxscores/?month=3&amp;day=16&amp;year=2024">Mar 16, 2024</a>,
#  <a href="/boxscores/202403150CHO.html">F<span class="no_mobile">inal</span></a>,
#  <a href="/boxscores/202403150CHO.html">Box Score</a>,
#  <a href="/boxscores/pbp/202403150CHO.html">Play-By-Play</a>,
#  <a href="/boxscores/shot-chart/202403150CHO.html">Shot Chart</a>,
#  <a href="/boxscores/202403150DET.html">F<span class="no_mobile">inal</span></a>,
#  <a href="/boxscores/202403150DET.html">Box Score</a>,
#  <a href="/boxscores/pbp/202403150DET.html">Play-By-Play</a>,
#  <a href="/boxscores/shot-chart/202403150DET.html">Shot Chart</a>,
#  <a href="/boxscores/202403150NOP.html">F<span class="no_mobile">inal</span></a>,
#  <a href="/boxscores/202403150NOP.html">Box Score</a>,
#  <a href="/boxscores/pbp/202403150NOP.html">Play-By-Play</a>,
#  <a href="/boxscores/shot-chart/202403150NOP.html">Shot Chart</a>,
#  <a href="/boxscores/202403150SAS.html">F<span class="no_mobile">inal</span></a>,
#  <a href="/boxscores/202403150SAS.html">Box Score</a>,
#  <a href="/boxscores/pbp/202403150SAS.html">Play-By-Play</a>,
#  <a href="/boxscores/shot-chart/202403150SAS.html">Shot Chart</a>,
#  <a href="/boxscores/202403150TOR.html">F<span class="no_mobile">inal</span></a>,
#  <a href="/boxscores/202403150TOR.html">Box Score</a>,
#  <a href="/boxscores/pbp/202403150TOR.html">Play-By-Play</a>,
#  <a href="/boxscores/shot-chart/202403150TOR.html">Shot Chart</a>,
#  <a href="/boxscores/202403150UTA.html">F<span class="no_mobile">inal</span></a>,
#  <a href="/boxscores/202403150UTA.html">Box Score</a>,
#  <a href="/boxscores/pbp/202403150UTA.html">Play-By-Play</a>,
#  <a href="/boxscores/shot-chart/202403150UTA.html">Shot Chart</a>,
#  <a href="/boxscores/" itemprop="item"><span itemprop="name">Box Scores</span></a>,
#  <a href="/boxscores/">NBA Scores</a>,
#  <a href="/boxscores/">Yesterday's Games</a>,
#  <a href="/boxscores/">Scores from any date in BAA/NBA or ABA history</a>]

# %%
# winning team score
print(int(game_on_date_test_soup.find('tbody').find_all('td')[1].contents[0]))

# winning team name
print(game_on_date_test_soup.find('tbody').find_all('td')[0].find('a').attrs['href'].split('/')[2])

# losing team score
print(int(game_on_date_test_soup.find('tbody').find_all('td')[4].contents[0]))

# losing team name
print(game_on_date_test_soup.find('tbody').find_all('td')[3].find('a').attrs['href'].split('/')[2])
# Out:
# 107
# PHO
# 96
# CHO

# %%
print(int(game_on_date_test_soup.find_all('tbody')[1].find_all('td')[1].contents[0]))
# Out:
# 28

# %%
print(game_on_date_test_soup.find_all('tbody'))
# Out:
# [<tbody>
# <tr class="winner">
# <td><a href="/teams/PHO/2024.html">Phoenix</a></td>
# <td class="right">107</td>
# <td class="right gamelink">
# <a href="/boxscores/202403150CHO.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="loser">
# <td><a href="/teams/CHO/2024.html">Charlotte</a></td>
# <td class="right">96</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>, <tbody>
# <tr>
# <td><a href="/teams/PHO/2024.html">Phoenix</a> </td>
# <td class="center">28</td><td class="center">26</td><td class="center">38</td><td class="center">15</td>
# </tr>
# <tr>
# <td><a href="/teams/CHO/2024.html">Charlotte</a> </td>
# <td class="center">26</td><td class="center">19</td><td class="center">22</td><td class="center">29</td>
# </tr>
# </tbody>, <tbody>
# <tr>
# <td><strong>PTS</strong></td>
# <td>2 tied</td>
# <td class="right">21</td>
# </tr>
# <tr>
# <td><strong>TRB</strong></td>
# <td><a href="/players/n/nurkiju01.html">J. Nurkić</a>-PHO</td>
# <td class="right">21</td>
# </tr>
# </tbody>, <tbody>
# <tr class="winner">
# <td><a href="/teams/MIA/2024.html">Miami</a></td>
# <td class="right">108</td>
# <td class="right gamelink">
# <a href="/boxscores/202403150DET.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="loser">
# <td><a href="/teams/DET/2024.html">Detroit</a></td>
# <td class="right">95</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>, <tbody>
# <tr>
# <td><a href="/teams/MIA/2024.html">Miami</a> </td>
# <td class="center">27</td><td class="center">29</td><td class="center">28</td><td class="center">24</td>
# </tr>
# <tr>
# <td><a href="/teams/DET/2024.html">Detroit</a> </td>
# <td class="center">28</td><td class="center">26</td><td class="center">18</td><td class="center">23</td>
# </tr>
# </tbody>, <tbody>
# <tr>
# <td><strong>PTS</strong></td>
# <td><a href="/players/f/fontesi01.html">S. Fontecchio</a>-DET</td>
# <td class="right">24</td>
# </tr>
# <tr>
# <td><strong>TRB</strong></td>
# <td><a href="/players/d/durenja01.html">J. Duren</a>-DET</td>
# <td class="right">17</td>
# </tr>
# </tbody>, <tbody>
# <tr class="loser">
# <td><a href="/teams/LAC/2024.html">LA Clippers</a></td>
# <td class="right">104</td>
# <td class="right gamelink">
# <a href="/boxscores/202403150NOP.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="winner">
# <td><a href="/teams/NOP/2024.html">New Orleans</a></td>
# <td class="right">112</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>, <tbody>
# <tr>
# <td><a href="/teams/LAC/2024.html">LA Clippers</a> </td>
# <td class="center">22</td><td class="center">22</td><td class="center">36</td><td class="center">24</td>
# </tr>
# <tr>
# <td><a href="/teams/NOP/2024.html">New Orleans</a> </td>
# <td class="center">20</td><td class="center">30</td><td class="center">32</td><td class="center">30</td>
# </tr>
# </tbody>, <tbody>
# <tr>
# <td><strong>PTS</strong></td>
# <td><a href="/players/w/willizi01.html">Z. Williamson</a>-NOP</td>
# <td class="right">34</td>
# </tr>
# <tr>
# <td><strong>TRB</strong></td>
# <td><a href="/players/z/zubaciv01.html">I. Zubac</a>-LAC</td>
# <td class="right">11</td>
# </tr>
# </tbody>, <tbody>
# <tr class="winner">
# <td><a href="/teams/DEN/2024.html">Denver</a></td>
# <td class="right">117</td>
# <td class="right gamelink">
# <a href="/boxscores/202403150SAS.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="loser">
# <td><a href="/teams/SAS/2024.html">San Antonio</a></td>
# <td class="right">106</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>, <tbody>
# <tr>
# <td><a href="/teams/DEN/2024.html">Denver</a> </td>
# <td class="center">37</td><td class="center">21</td><td class="center">28</td><td class="center">31</td>
# </tr>
# <tr>
# <td><a href="/teams/SAS/2024.html">San Antonio</a> </td>
# <td class="center">18</td><td class="center">31</td><td class="center">30</td><td class="center">27</td>
# </tr>
# </tbody>, <tbody>
# <tr>
# <td><strong>PTS</strong></td>
# <td><a href="/players/j/jokicni01.html">N. Jokić</a>-DEN</td>
# <td class="right">31</td>
# </tr>
# <tr>
# <td><strong>TRB</strong></td>
# <td><a href="/players/m/murraja01.html">J. Murray</a>-DEN</td>
# <td class="right">10</td>
# </tr>
# </tbody>, <tbody>
# <tr class="winner">
# <td><a href="/teams/ORL/2024.html">Orlando</a></td>
# <td class="right">113</td>
# <td class="right gamelink">
# <a href="/boxscores/202403150TOR.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="loser">
# <td><a href="/teams/TOR/2024.html">Toronto</a></td>
# <td class="right">103</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>, <tbody>
# <tr>
# <td><a href="/teams/ORL/2024.html">Orlando</a> </td>
# <td class="center">24</td><td class="center">26</td><td class="center">34</td><td class="center">29</td>
# </tr>
# <tr>
# <td><a href="/teams/TOR/2024.html">Toronto</a> </td>
# <td class="center">27</td><td class="center">21</td><td class="center">25</td><td class="center">30</td>
# </tr>
# </tbody>, <tbody>
# <tr>
# <td><strong>PTS</strong></td>
# <td><a href="/players/t/trentga02.html">G. Trent</a>-TOR</td>
# <td class="right">31</td>
# </tr>
# <tr>
# <td><strong>TRB</strong></td>
# <td>2 tied</td>
# <td class="right">9</td>
# </tr>
# </tbody>, <tbody>
# <tr class="loser">
# <td><a href="/teams/ATL/2024.html">Atlanta</a></td>
# <td class="right">122</td>
# <td class="right gamelink">
# <a href="/boxscores/202403150UTA.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="winner">
# <td><a href="/teams/UTA/2024.html">Utah</a></td>
# <td class="right">124</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>, <tbody>
# <tr>
# <td><a href="/teams/ATL/2024.html">Atlanta</a> </td>
# <td class="center">28</td><td class="center">34</td><td class="center">34</td><td class="center">26</td>
# </tr>
# <tr>
# <td><a href="/teams/UTA/2024.html">Utah</a> </td>
# <td class="center">34</td><td class="center">27</td><td class="center">37</td><td class="center">26</td>
# </tr>
# </tbody>, <tbody>
# <tr>
# <td><strong>PTS</strong></td>
# <td><a href="/players/m/murrade01.html">D. Murray</a>-ATL</td>
# <td class="right">33</td>
# </tr>
# <tr>
# <td><strong>TRB</strong></td>
# <td><a href="/players/c/capelca01.html">C. Capela</a>-ATL</td>
# <td class="right">15</td>
# </tr>
# </tbody>, <tbody><tr class="full_table"><th class="left" csk="0.212" data-stat="team_name" scope="row"><a href="/teams/BOS/2024.html">Boston Celtics</a>*</th><td class="right" data-stat="wins">52</td><td class="right" data-stat="losses">14</td><td class="right" data-stat="win_loss_pct">.788</td><td class="right" data-stat="gb">—</td><td class="right" data-stat="pts_per_g">120.9</td><td class="right" data-stat="opp_pts_per_g">109.7</td></tr>
# <tr class="full_table"><th class="left" csk="0.358" data-stat="team_name" scope="row"><a href="/teams/MIL/2024.html">Milwaukee Bucks</a>*</th><td class="right" data-stat="wins">43</td><td class="right" data-stat="losses">24</td><td class="right" data-stat="win_loss_pct">.642</td><td class="right" data-stat="gb">9.5</td><td class="right" data-stat="pts_per_g">120.4</td><td class="right" data-stat="opp_pts_per_g">117.1</td></tr>
# <tr class="full_table"><th class="left" csk="0.364" data-stat="team_name" scope="row"><a href="/teams/CLE/2024.html">Cleveland Cavaliers</a>*</th><td class="right" data-stat="wins">42</td><td class="right" data-stat="losses">24</td><td class="right" data-stat="win_loss_pct">.636</td><td class="right" data-stat="gb">10.0</td><td class="right" data-stat="pts_per_g">113.8</td><td class="right" data-stat="opp_pts_per_g">109.4</td></tr>
# <tr class="full_table"><th class="left" csk="0.409" data-stat="team_name" scope="row"><a href="/teams/NYK/2024.html">New York Knicks</a>*</th><td class="right" data-stat="wins">39</td><td class="right" data-stat="losses">27</td><td class="right" data-stat="win_loss_pct">.591</td><td class="right" data-stat="gb">13.0</td><td class="right" data-stat="pts_per_g">112.2</td><td class="right" data-stat="opp_pts_per_g">108.1</td></tr>
# <tr class="full_table"><th class="left" csk="0.418" data-stat="team_name" scope="row"><a href="/teams/ORL/2024.html">Orlando Magic</a>*</th><td class="right" data-stat="wins">39</td><td class="right" data-stat="losses">28</td><td class="right" data-stat="win_loss_pct">.582</td><td class="right" data-stat="gb">13.5</td><td class="right" data-stat="pts_per_g">110.7</td><td class="right" data-stat="opp_pts_per_g">109.2</td></tr>
# <tr class="full_table"><th class="left" csk="0.448" data-stat="team_name" scope="row"><a href="/teams/IND/2024.html">Indiana Pacers</a>*</th><td class="right" data-stat="wins">37</td><td class="right" data-stat="losses">30</td><td class="right" data-stat="win_loss_pct">.552</td><td class="right" data-stat="gb">15.5</td><td class="right" data-stat="pts_per_g">123.1</td><td class="right" data-stat="opp_pts_per_g">121.4</td></tr>
# <tr class="full_table"><th class="left" csk="0.455" data-stat="team_name" scope="row"><a href="/teams/MIA/2024.html">Miami Heat</a>*</th><td class="right" data-stat="wins">36</td><td class="right" data-stat="losses">30</td><td class="right" data-stat="win_loss_pct">.545</td><td class="right" data-stat="gb">16.0</td><td class="right" data-stat="pts_per_g">110.1</td><td class="right" data-stat="opp_pts_per_g">109.6</td></tr>
# <tr class="full_table"><th class="left" csk="0.455" data-stat="team_name" scope="row"><a href="/teams/PHI/2024.html">Philadelphia 76ers</a>*</th><td class="right" data-stat="wins">36</td><td class="right" data-stat="losses">30</td><td class="right" data-stat="win_loss_pct">.545</td><td class="right" data-stat="gb">16.0</td><td class="right" data-stat="pts_per_g">115.2</td><td class="right" data-stat="opp_pts_per_g">112.9</td></tr>
# <tr class="full_table"><th class="left" csk="0.522" data-stat="team_name" scope="row"><a href="/teams/CHI/2024.html">Chicago Bulls</a></th><td class="right" data-stat="wins">32</td><td class="right" data-stat="losses">35</td><td class="right" data-stat="win_loss_pct">.478</td><td class="right" data-stat="gb">20.5</td><td class="right" data-stat="pts_per_g">111.8</td><td class="right" data-stat="opp_pts_per_g">113.9</td></tr>
# <tr class="full_table"><th class="left" csk="0.561" data-stat="team_name" scope="row"><a href="/teams/ATL/2024.html">Atlanta Hawks</a></th><td class="right" data-stat="wins">29</td><td class="right" data-stat="losses">37</td><td class="right" data-stat="win_loss_pct">.439</td><td class="right" data-stat="gb">23.0</td><td class="right" data-stat="pts_per_g">119.4</td><td class="right" data-stat="opp_pts_per_g">121.3</td></tr>
# <tr class="full_table"><th class="left" csk="0.606" data-stat="team_name" scope="row"><a href="/teams/BRK/2024.html">Brooklyn Nets</a></th><td class="right" data-stat="wins">26</td><td class="right" data-stat="losses">40</td><td class="right" data-stat="win_loss_pct">.394</td><td class="right" data-stat="gb">26.0</td><td class="right" data-stat="pts_per_g">111.8</td><td class="right" data-stat="opp_pts_per_g">113.9</td></tr>
# <tr class="full_table"><th class="left" csk="0.657" data-stat="team_name" scope="row"><a href="/teams/TOR/2024.html">Toronto Raptors</a></th><td class="right" data-stat="wins">23</td><td class="right" data-stat="losses">44</td><td class="right" data-stat="win_loss_pct">.343</td><td class="right" data-stat="gb">29.5</td><td class="right" data-stat="pts_per_g">113.9</td><td class="right" data-stat="opp_pts_per_g">118.1</td></tr>
# <tr class="full_table"><th class="left" csk="0.746" data-stat="team_name" scope="row"><a href="/teams/CHO/2024.html">Charlotte Hornets</a></th><td class="right" data-stat="wins">17</td><td class="right" data-stat="losses">50</td><td class="right" data-stat="win_loss_pct">.254</td><td class="right" data-stat="gb">35.5</td><td class="right" data-stat="pts_per_g">106.9</td><td class="right" data-stat="opp_pts_per_g">116.8</td></tr>
# <tr class="full_table"><th class="left" csk="0.818" data-stat="team_name" scope="row"><a href="/teams/DET/2024.html">Detroit Pistons</a></th><td class="right" data-stat="wins">12</td><td class="right" data-stat="losses">54</td><td class="right" data-stat="win_loss_pct">.182</td><td class="right" data-stat="gb">40.0</td><td class="right" data-stat="pts_per_g">112.1</td><td class="right" data-stat="opp_pts_per_g">120.3</td></tr>
# <tr class="full_table"><th class="left" csk="0.833" data-stat="team_name" scope="row"><a href="/teams/WAS/2024.html">Washington Wizards</a></th><td class="right" data-stat="wins">11</td><td class="right" data-stat="losses">55</td><td class="right" data-stat="win_loss_pct">.167</td><td class="right" data-stat="gb">41.0</td><td class="right" data-stat="pts_per_g">114.2</td><td class="right" data-stat="opp_pts_per_g">123.9</td></tr>
# </tbody>, <tbody><tr class="full_table"><th class="left" csk="0.299" data-stat="team_name" scope="row"><a href="/teams/DEN/2024.html">Denver Nuggets</a>*</th><td class="right" data-stat="wins">47</td><td class="right" data-stat="losses">20</td><td class="right" data-stat="win_loss_pct">.701</td><td class="right" data-stat="gb">—</td><td class="right" data-stat="pts_per_g">114.8</td><td class="right" data-stat="opp_pts_per_g">110.3</td></tr>
# <tr class="full_table"><th class="left" csk="0.303" data-stat="team_name" scope="row"><a href="/teams/OKC/2024.html">Oklahoma City Thunder</a>*</th><td class="right" data-stat="wins">46</td><td class="right" data-stat="losses">20</td><td class="right" data-stat="win_loss_pct">.697</td><td class="right" data-stat="gb">0.5</td><td class="right" data-stat="pts_per_g">120.8</td><td class="right" data-stat="opp_pts_per_g">113.1</td></tr>
# <tr class="full_table"><th class="left" csk="0.318" data-stat="team_name" scope="row"><a href="/teams/MIN/2024.html">Minnesota Timberwolves</a>*</th><td class="right" data-stat="wins">45</td><td class="right" data-stat="losses">21</td><td class="right" data-stat="win_loss_pct">.682</td><td class="right" data-stat="gb">1.5</td><td class="right" data-stat="pts_per_g">113.2</td><td class="right" data-stat="opp_pts_per_g">106.7</td></tr>
# <tr class="full_table"><th class="left" csk="0.364" data-stat="team_name" scope="row"><a href="/teams/LAC/2024.html">Los Angeles Clippers</a>*</th><td class="right" data-stat="wins">42</td><td class="right" data-stat="losses">24</td><td class="right" data-stat="win_loss_pct">.636</td><td class="right" data-stat="gb">4.5</td><td class="right" data-stat="pts_per_g">116.8</td><td class="right" data-stat="opp_pts_per_g">112.7</td></tr>
# <tr class="full_table"><th class="left" csk="0.394" data-stat="team_name" scope="row"><a href="/teams/NOP/2024.html">New Orleans Pelicans</a>*</th><td class="right" data-stat="wins">40</td><td class="right" data-stat="losses">26</td><td class="right" data-stat="win_loss_pct">.606</td><td class="right" data-stat="gb">6.5</td><td class="right" data-stat="pts_per_g">116.0</td><td class="right" data-stat="opp_pts_per_g">111.1</td></tr>
# <tr class="full_table"><th class="left" csk="0.415" data-stat="team_name" scope="row"><a href="/teams/SAC/2024.html">Sacramento Kings</a></th><td class="right" data-stat="wins">38</td><td class="right" data-stat="losses">27</td><td class="right" data-stat="win_loss_pct">.585</td><td class="right" data-stat="gb">8.0</td><td class="right" data-stat="pts_per_g">118.4</td><td class="right" data-stat="opp_pts_per_g">117.4</td></tr>
# <tr class="full_table"><th class="left" csk="0.418" data-stat="team_name" scope="row"><a href="/teams/PHO/2024.html">Phoenix Suns</a>*</th><td class="right" data-stat="wins">39</td><td class="right" data-stat="losses">28</td><td class="right" data-stat="win_loss_pct">.582</td><td class="right" data-stat="gb">8.0</td><td class="right" data-stat="pts_per_g">116.8</td><td class="right" data-stat="opp_pts_per_g">114.2</td></tr>
# <tr class="full_table"><th class="left" csk="0.433" data-stat="team_name" scope="row"><a href="/teams/DAL/2024.html">Dallas Mavericks</a>*</th><td class="right" data-stat="wins">38</td><td class="right" data-stat="losses">29</td><td class="right" data-stat="win_loss_pct">.567</td><td class="right" data-stat="gb">9.0</td><td class="right" data-stat="pts_per_g">119.0</td><td class="right" data-stat="opp_pts_per_g">117.7</td></tr>
# <tr class="full_table"><th class="left" csk="0.463" data-stat="team_name" scope="row"><a href="/teams/LAL/2024.html">Los Angeles Lakers</a>*</th><td class="right" data-stat="wins">36</td><td class="right" data-stat="losses">31</td><td class="right" data-stat="win_loss_pct">.537</td><td class="right" data-stat="gb">11.0</td><td class="right" data-stat="pts_per_g">117.1</td><td class="right" data-stat="opp_pts_per_g">117.6</td></tr>
# <tr class="full_table"><th class="left" csk="0.477" data-stat="team_name" scope="row"><a href="/teams/GSW/2024.html">Golden State Warriors</a></th><td class="right" data-stat="wins">34</td><td class="right" data-stat="losses">31</td><td class="right" data-stat="win_loss_pct">.523</td><td class="right" data-stat="gb">12.0</td><td class="right" data-stat="pts_per_g">118.2</td><td class="right" data-stat="opp_pts_per_g">116.7</td></tr>
# <tr class="full_table"><th class="left" csk="0.530" data-stat="team_name" scope="row"><a href="/teams/HOU/2024.html">Houston Rockets</a></th><td class="right" data-stat="wins">31</td><td class="right" data-stat="losses">35</td><td class="right" data-stat="win_loss_pct">.470</td><td class="right" data-stat="gb">15.5</td><td class="right" data-stat="pts_per_g">113.2</td><td class="right" data-stat="opp_pts_per_g">112.6</td></tr>
# <tr class="full_table"><th class="left" csk="0.561" data-stat="team_name" scope="row"><a href="/teams/UTA/2024.html">Utah Jazz</a></th><td class="right" data-stat="wins">29</td><td class="right" data-stat="losses">37</td><td class="right" data-stat="win_loss_pct">.439</td><td class="right" data-stat="gb">17.5</td><td class="right" data-stat="pts_per_g">117.7</td><td class="right" data-stat="opp_pts_per_g">120.8</td></tr>
# <tr class="full_table"><th class="left" csk="0.657" data-stat="team_name" scope="row"><a href="/teams/MEM/2024.html">Memphis Grizzlies</a></th><td class="right" data-stat="wins">23</td><td class="right" data-stat="losses">44</td><td class="right" data-stat="win_loss_pct">.343</td><td class="right" data-stat="gb">24.0</td><td class="right" data-stat="pts_per_g">105.7</td><td class="right" data-stat="opp_pts_per_g">112.2</td></tr>
# <tr class="full_table"><th class="left" csk="0.712" data-stat="team_name" scope="row"><a href="/teams/POR/2024.html">Portland Trail Blazers</a></th><td class="right" data-stat="wins">19</td><td class="right" data-stat="losses">47</td><td class="right" data-stat="win_loss_pct">.288</td><td class="right" data-stat="gb">27.5</td><td class="right" data-stat="pts_per_g">107.7</td><td class="right" data-stat="opp_pts_per_g">115.7</td></tr>
# <tr class="full_table"><th class="left" csk="0.791" data-stat="team_name" scope="row"><a href="/teams/SAS/2024.html">San Antonio Spurs</a></th><td class="right" data-stat="wins">14</td><td class="right" data-stat="losses">53</td><td class="right" data-stat="win_loss_pct">.209</td><td class="right" data-stat="gb">33.0</td><td class="right" data-stat="pts_per_g">112.2</td><td class="right" data-stat="opp_pts_per_g">119.8</td></tr>
# </tbody>]

# %%
game_on_date_test_soup.find_all('tr', {"class": "winner"})[0]
# Out:
# <tr class="winner">
# <td><a href="/teams/PHO/2024.html">Phoenix</a></td>
# <td class="right">107</td>
# <td class="right gamelink">
# <a href="/boxscores/202403150CHO.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>

# %%
game_on_date_test_soup.find_all('tr')[2]
# Out:
# <tr>
# <th></th><!-- the team labels -->
# <th>1</th><th>2</th><th>3</th><th>4</th>
# </tr>

# %%
game_on_date_test_soup.find_all('tr', {"class": "winner"})[1].find_all('a')[1].attrs['href'].split('/')[2].split('.')[0][-3:]
# Out:
# 'DET'

# %%
game_on_date_test_soup.find_all('tr', {"class": "winner"})[0].find_all('td')[0].find('a').attrs['href'].split('/')[2]
# Out:
# 'PHO'

# %%
#print(game_on_date_test_soup.find('tbody').find_all('td')[0].find('a').attrs['href'].split('/')[2])
print(int(game_on_date_test_soup.find_all('tr', {"class": "winner"})[3].find_all('td')[1].contents[0]))
# Out:
# 117

# %%
date = '20230315'

year = date[:4]
month = date[4:6]
day = date[-2:]

print(year + " " + month + " " + day)
# Out:
# 2023 03 15

# %%
# Probably best to create individual series for each datapoint, ie loser score, then create the df at the end

def get_game_results(date):
    
    # need to incorporate game date into function

    #yyyymmdd
    #date = '20230315'

    year = date[:4]
    month = date[4:6]
    day = date[-2:]
    
    games_on_date_test_url = 'https://www.basketball-reference.com/boxscores/?month='  + str(int(month)) + '&day=' + str(int(day)) + '&year=' + str(int(year))

    games_on_date_test_page = requests.get(games_on_date_test_url,params={
      'render_js': True})    

    game_on_date_test_soup = BeautifulSoup(games_on_date_test_page.text, 'lxml')

    #game_results_df = pd.DataFrame()

    winning_teams = []
    losing_teams = []
    winning_scores = []
    losing_scores = []
    home_teams = []

    for i in range(len(game_on_date_test_soup.find_all('tr', {"class": "winner"}))):
        
      winning_teams.append(game_on_date_test_soup.find_all('tr', {"class": "winner"})[i].find_all('td')[0].find('a').attrs['href'].split('/')[2])
      losing_teams.append(game_on_date_test_soup.find_all('tr', {"class": "loser"})[i].find_all('td')[0].find('a').attrs['href'].split('/')[2])

      winning_scores.append(int(game_on_date_test_soup.find_all('tr', {"class": "winner"})[i].find_all('td')[1].contents[0]))
      losing_scores.append(int(game_on_date_test_soup.find_all('tr', {"class": "loser"})[i].find_all('td')[1].contents[0]))

      #home_teams.append(game_on_date_test_soup.find_all('tr', {"class": "winner"})[i].find_all('a')[1].attrs['href'].split('/')[2].split('.')[0][-3:])

    for i in range(len(game_on_date_test_soup.find_all('tr', {'class':['winner', 'loser']}))):
      try:
        home_teams.append(game_on_date_test_soup.find_all('tr', {'class':['winner', 'loser']})[i].find('a', href=re.compile('/boxscores/')).attrs['href'].split('/')[2].split('.')[0][-3:])
      except:
        pass

    temp_df = pd.DataFrame({'home': home_teams, 'winning_team': winning_teams, 'losing_team': losing_teams, 'winning_score': winning_scores, 'losing_score': losing_scores})
    
    temp_df['visitor'] = temp_df.apply(lambda x: x.winning_team if x.winning_team != x.home else x.losing_team, axis = 1)

    temp_df['visitor_score'] = temp_df.apply(lambda x: x.winning_score if x.winning_team != x.home else x.losing_score, axis = 1)

    temp_df['home_score'] = temp_df.apply(lambda x: x.winning_score if x.winning_team == x.home else x.losing_score, axis = 1)

    temp_df['dates'] = date

    temp_df['id'] = temp_df['visitor'] + temp_df['home'] + temp_df['dates']

    final_df = temp_df[['id', 'visitor', 'home', 'dates', 'visitor_score', 'home_score']]

    #temp_df['visiting_team'] = temp_df.apply(lambda x: x.winning_team if x.winning_team != x.home_team else x.losing_team)#[x for x in temp_df['winning_team']]
    return(final_df)
    #print(winning_teams)
    #print(losing_teams)
    #print(winning_scores)
    #print(losing_scores)
    #print(home_teams)

    # id = visitor initial + home initial + YYYYMMDD
    # visitor
    # home
    # date
    # visitor score
    # home score

# %%
# Probably best to create individual series for each datapoint, ie loser score, then create the df at the end

def get_game_results_w_api(date):
    
    # need to incorporate game date into function

    #yyyymmdd
    #date = '20230315'

    year = date[:4]
    month = date[4:6]
    day = date[-2:]
    
    games_on_date_test_url = 'https://www.basketball-reference.com/boxscores/?month='  + str(int(month)) + '&day=' + str(int(day)) + '&year=' + str(int(year))

    payload = { 'api_key': '1e39e30a6e96d4b3c90d44ae0e3222e2', 'url': games_on_date_test_url, 'country_code': 'us', 'device_type': 'desktop', 'max_cost': '1000', 'session_number': '0', 'render_js': True}
    
    games_on_date_test_page = requests.get('https://api.scraperapi.com/', params=payload)

    #games_on_date_test_page = requests.get(games_on_date_test_url,params={
    #  'render_js': True})   

    game_on_date_test_soup = BeautifulSoup(games_on_date_test_page.text, 'lxml')

    #game_results_df = pd.DataFrame()

    winning_teams = []
    losing_teams = []
    winning_scores = []
    losing_scores = []
    home_teams = []

    for i in range(len(game_on_date_test_soup.find_all('tr', {"class": "winner"}))):
        
      winning_teams.append(game_on_date_test_soup.find_all('tr', {"class": "winner"})[i].find_all('td')[0].find('a').attrs['href'].split('/')[2])
      losing_teams.append(game_on_date_test_soup.find_all('tr', {"class": "loser"})[i].find_all('td')[0].find('a').attrs['href'].split('/')[2])

      winning_scores.append(int(game_on_date_test_soup.find_all('tr', {"class": "winner"})[i].find_all('td')[1].contents[0]))
      losing_scores.append(int(game_on_date_test_soup.find_all('tr', {"class": "loser"})[i].find_all('td')[1].contents[0]))

      #home_teams.append(game_on_date_test_soup.find_all('tr', {"class": "winner"})[i].find_all('a')[1].attrs['href'].split('/')[2].split('.')[0][-3:])

    for i in range(len(game_on_date_test_soup.find_all('tr', {'class':['winner', 'loser']}))):
      try:
        home_teams.append(game_on_date_test_soup.find_all('tr', {'class':['winner', 'loser']})[i].find('a', href=re.compile('/boxscores/')).attrs['href'].split('/')[2].split('.')[0][-3:])
      except:
        pass

    temp_df = pd.DataFrame({'home': home_teams, 'winning_team': winning_teams, 'losing_team': losing_teams, 'winning_score': winning_scores, 'losing_score': losing_scores})
    
    temp_df['visitor'] = temp_df.apply(lambda x: x.winning_team if x.winning_team != x.home else x.losing_team, axis = 1)

    temp_df['visitor_score'] = temp_df.apply(lambda x: x.winning_score if x.winning_team != x.home else x.losing_score, axis = 1)

    temp_df['home_score'] = temp_df.apply(lambda x: x.winning_score if x.winning_team == x.home else x.losing_score, axis = 1)

    temp_df['dates'] = date

    temp_df['id'] = temp_df['visitor'] + temp_df['home'] + temp_df['dates']

    final_df = temp_df[['id', 'visitor', 'home', 'dates', 'visitor_score', 'home_score']]

    #temp_df['visiting_team'] = temp_df.apply(lambda x: x.winning_team if x.winning_team != x.home_team else x.losing_team)#[x for x in temp_df['winning_team']]
    return(final_df)
    #print(winning_teams)
    #print(losing_teams)
    #print(winning_scores)
    #print(losing_scores)
    #print(home_teams)

    # id = visitor initial + home initial + YYYYMMDD
    # visitor
    # home
    # date
    # visitor score
    # home score

# %%
get_game_results_w_api('20240315')
# Out:
#                id visitor home     dates  visitor_score  home_score
# 0  PHOCHO20240315     PHO  CHO  20240315            107          96
# 1  MIADET20240315     MIA  DET  20240315            108          95
# 2  LACNOP20240315     LAC  NOP  20240315            104         112
# 3  DENSAS20240315     DEN  SAS  20240315            117         106
# 4  ORLTOR20240315     ORL  TOR  20240315            113         103
# 5  ATLUTA20240315     ATL  UTA  20240315            122         124

# %%
get_game_results('20240315')
# Out:
#                id visitor home     dates  visitor_score  home_score
# 0  PHOCHO20240315     PHO  CHO  20240315            107          96
# 1  MIADET20240315     MIA  DET  20240315            108          95
# 2  LACNOP20240315     LAC  NOP  20240315            104         112
# 3  DENSAS20240315     DEN  SAS  20240315            117         106
# 4  ORLTOR20240315     ORL  TOR  20240315            113         103
# 5  ATLUTA20240315     ATL  UTA  20240315            122         124

# %%
def config(filename = 'database.ini', section = 'postgresql'):
    parser = ConfigParser()
    parser.read(filename)

    db = {}

    if parser.has_section(section):
        params = parser.items(section)

        for param in params:
            db[param[0]] = param[1]

    else:
        raise Exception('Section{0} is not found in the {1} file'.format(section, filename))
    
    return(db)

#config()

# %%
df_test = get_game_results('20240315')

for index in df_test.index:
    #print(tuple(df_test.iloc[row].values[0]))
    print(tuple(df_test.iloc[index]))
# Out:
# ('PHOCHO20240315', 'PHO', 'CHO', '20240315', 107, 96)
# ('MIADET20240315', 'MIA', 'DET', '20240315', 108, 95)
# ('LACNOP20240315', 'LAC', 'NOP', '20240315', 104, 112)
# ('DENSAS20240315', 'DEN', 'SAS', '20240315', 117, 106)
# ('ORLTOR20240315', 'ORL', 'TOR', '20240315', 113, 103)
# ('ATLUTA20240315', 'ATL', 'UTA', '20240315', 122, 124)

# %%
def create_sql_tables():
    connection = None
    try:
        params = config()
        #print(params)
        print('connecting to postgresql database...')
        connection = psycopg2.connect(**params)
       
        # create cursor
        cursor = connection.cursor()
        
        # add all sql create table commands here
        #cursor.execute(open('create_game_results_table.sql', 'r').read())
        #cursor.execute(open('create_yearly_team_per_game_stats_table.sql', 'r').read())
        #cursor.execute(open('create_yearly_opponent_per_game_stats_table.sql', 'r').read())

        try:
            
            # add all sql create table commands here
            #cursor.execute(open('create_game_results_table.sql', 'r').read())
            #cursor.execute(open('create_yearly_team_per_game_stats_table.sql', 'r').read())
            #cursor.execute(open('create_yearly_opponent_per_game_stats_table.sql', 'r').read())


            connection.commit()
            print("connection successful / task complete")
            cursor.close()
            #os.remove(tmp_df)
            
        except (Exception, psycopg2.DatabaseError) as error:
            #os.remove(tmp_df)
            print("Error: %s" % error)
            #connection.rollback()
            cursor.close()
            return 1
    
    except(Exception, psycopg2.DatabaseError) as error:
        print(error)
    
    finally:
        if connection is not None:
            connection.close()
            print('database connection terminated')

if __name__ == '__main__':
    create_sql_tables()
# Out:
# connecting to postgresql database...
# connection successful / task complete
# database connection terminated

# %%
def get_dates_already_in_db():
    connection = None
    try:
        params = config()
        #print(params)
        print('connecting to postgresql database...')
        connection = psycopg2.connect(**params)
       
        # create cursor
        cursor = connection.cursor()

        try:
            
            cursor.execute("""SELECT DISTINCT(dates) FROM game_results;""")

            game_dates_already_in_db = cursor.fetchall()

            connection.commit()
            print("connection successful / task complete")
            cursor.close()
            return game_dates_already_in_db
            #os.remove(tmp_df)
            
        except (Exception, psycopg2.DatabaseError) as error:
            #os.remove(tmp_df)
            print("Error: %s" % error)
            #connection.rollback()
            cursor.close()
            return 1
    
    except(Exception, psycopg2.DatabaseError) as error:
        print(error)
    
    finally:
        if connection is not None:
            connection.close()
            print('database connection terminated')

if __name__ == '__main__':
    get_dates_already_in_db()
# Out:
# connecting to postgresql database...
# connection successful / task complete
# database connection terminated

# %%
existing_game_dates_raw = get_dates_already_in_db()
# Out:
# connecting to postgresql database...
# connection successful / task complete
# database connection terminated

# %%
existing_game_dates_clean = [x[0] for x in existing_game_dates_raw]
existing_game_dates_clean.sort(reverse=True)

# %%
print(existing_game_dates_clean)
# Out:
, 20230316, 20230315, 20230314, 20230313, 20230312, 20230311, 20230310, 20230309, 20230308, 20230307, 20230306, 20230305, 20230304, 20230303, 20230302, 20230301, 20230228, 20230227, 20230226, 20230225, 20230224, 20230223, 20230216, 20230215, 20230214, 20230213, 20230212, 20230211, 20230210, 20230209, 20230208, 20230207, 20230206, 20230205, 20230204, 20230203, 20230202, 20230201, 20230131, 20230130, 20230129, 20230128, 20230127, 20230126, 20230125, 20230124, 20230123, 20230122, 20230121, 20230120, 20230119, 20230118, 20230117, 20230116, ...

# %%
regular_season_dates = {
  2000: [19991031, 20000416],
  2001: [20001031, 20010418],
  2002: [20011030, 20020417],
  2003: [20021029, 20030416],
  2004: [20031028, 20040414],
  2005: [20041102, 20050420],
  2006: [20051101, 20060419],
  2007: [20061031, 20070415],
  2008: [20071030, 20080416],
  2009: [20081028, 20090415],
  2010: [20091027, 20100414],
  2011: [20101026, 20110413],
  2012: [20111225, 20120426],
  2013: [20121030, 20130417],
  2014: [20131029, 20140416],
  2015: [20141028, 20150415],
  2016: [20151027, 20160413],
  2017: [20161025, 20170412],
  2018: [20171017, 20180411],
  2019: [20181016, 20190410],
  2020: [20191022, 20200311],
  2021: [20201222, 20210716],
  2022: [20211019, 20220410],
  2023: [20221018, 20230409],
  2024: [20231024, 20230414],
  2025: [20241028, 20250413]
}

playoff_dates = {
  2000: [20000421, 20000619],
  2001: [20010420, 20010615],
  2002: [20020419, 20020616],
  2003: [20030418, 20030615],
  2004: [20040416, 20040615],
  2005: [20050423, 20050623],
  2006: [20060421, 20060620],
  2007: [20070420, 20070614],
  2008: [20080418, 20080617],
  2009: [20090418, 20090614],
  2010: [20100417, 20100617],
  2011: [20110416, 20110612],
  2012: [20120428, 20120621],
  2013: [20130420, 20130620],
  2014: [20140419, 20140615],
  2015: [20150418, 20150616],
  2016: [20160416, 20160619],
  2017: [20170415, 20170612],
  2018: [20180414, 20180608],
  2019: [20190413, 20190613],
  2020: [20200817, 20201011],
  2021: [20210522, 20210720],
  2022: [20220416, 20220616],
  2023: [20230415, 20230618],
  2024: [20240420, 20240616],
  2025: [20250418, 20250615]
}

# %%
def add_game_data_to_db(date):
    connection = None
    try:
        params = config()
        #print(params)
        print('connecting to postgresql database...')
        connection = psycopg2.connect(**params)
       
        # create cursor
        cursor = connection.cursor()
        
        # example
        #print('postgresql database version: ')
        #crsr.execute('SELECT version()')
        #db_version = crsr.fetchone()
        #print(db_version)

        try:
            #cursor.copy_from(f, 'game_results', sep=",")
            #cursor.copy_from(f_21_22, 'game_results', sep=",")
            #cursor.copy_from(f_19, 'game_results', sep=",")
            #cursor.copy_from(f_17_18, 'game_results', sep=",")
            #cursor.copy_from(f_15_16, 'game_results', sep=",")
            #cursor.copy_from(f_13_14, 'game_results', sep=",")

            #cursor.copy_from(f_team_per_game_stats, 'yearly_team_per_game_stats', sep=",")
            #cursor.copy_from(f_opp_per_game_stats, 'yearly_opponent_per_game_stats', sep=",")
            
            #cursor.copy_from(final_df_csv, 'game_results')

            #cursor.execute("""INSERT INTO game_results (id, visitor, home, dates, visitor_score, home_score) VALUES (%s, %s, %s, %s, %s, %s); """, tuple(df_test.iloc[0]))

            game_data_on_date = get_game_results_w_api(str(date))
            for index in game_data_on_date.index:
                cursor.execute("""INSERT INTO game_results (id, visitor, home, dates, visitor_score, home_score) VALUES (%s, %s, %s, %s, %s, %s); """, tuple(game_data_on_date.iloc[index]))

            connection.commit()
            #print("connection successful / task complete")
            cursor.close()
            #os.remove(tmp_df)
            
        except (Exception, psycopg2.DatabaseError) as error:
            #os.remove(tmp_df)
            print("Error: %s" % error)
            #connection.rollback()
            cursor.close()
            return 1
    
    except(Exception, psycopg2.DatabaseError) as error:
        print(error)
    
    finally:
        if connection is not None:
            connection.close()
           #print('database connection terminated')

#if __name__ == '__main__':
#    get_game_data('20240315')

# %%
#add_game_data_to_db('20240315')

# %%
from datetime import date, timedelta

valid_game_days = []

start_date = date.today() 
end_date = date(1999, 10, 31)    # perhaps date.today()

delta = start_date - end_date   # returns timedelta

for i in range(delta.days + 1):
    day = str(start_date - timedelta(days=i))
    day = int(day.replace("-", ""))
    month = (day // 100) % 100
    year = day // 10000
    if month > 8 and day >= regular_season_dates[year + 1][0]:
        valid_game_days.append(day)
    elif day <= playoff_dates[year][1]:
        valid_game_days.append(day)

# %%
valid_game_days
# Out:
# [20250108,
#  20250107,
#  20250106,
#  20250105,
#  20250104,
#  20250103,
#  20250102,
#  20250101,
#  20241231,
#  20241230,
#  20241229,
#  20241228,
#  20241227,
#  20241226,
#  20241225,
#  20241224,
#  20241223,
#  20241222,
#  20241221,
#  20241220,
#  20241219,
#  20241218,
#  20241217,
#  20241216,
#  20241215,
#  20241214,
#  20241213,
#  20241212,
#  20241211,
#  20241210,
#  20241209,
#  20241208,
#  20241207,
#  20241206,
#  20241205,
#  20241204,
#  20241203,
#  20241202,
#  20241201,
#  20241130,
#  20241129,
#  20241128,
#  20241127,
#  20241126,
#  20241125,
#  20241124,
#  20241123,
#  20241122,
#  20241121,
#  20241120,
#  20241119,
#  20241118,
#  20241117,
#  20241116,
#  20241115,
#  20241114,
#  20241113,
#  20241112,
#  20241111,
#  20241110,
#  20241109,
#  20241108,
#  20241107,
#  20241106,
#  20241105,
#  20241104,
#  20241103,
#  20241102,
#  20241101,
#  20241031,
#  20241030,
#  20241029,
#  20241028,
#  20240616,
#  20240615,
#  20240614,
#  20240613,
#  20240612,
#  20240611,
#  20240610,
#  20240609,
#  20240608,
#  20240607,
#  20240606,
#  20240605,
#  20240604,
#  20240603,
#  20240602,
#  20240601,
#  20240531,
#  20240530,
#  20240529,
#  20240528,
#  20240527,
#  20240526,
#  20240525,
#  20240524,
#  20240523,
#  20240522,
#  20240521,
#  20240520,
#  20240519,
#  20240518,
#  20240517,
#  20240516,
#  20240515,
#  20240514,
#  20240513,
#  20240512,
#  20240511,
#  20240510,
#  20240509,
#  20240508,
#  20240507,
#  20240506,
#  20240505,
#  20240504,
#  20240503,
#  20240502,
#  20240501,
#  20240430,
#  20240429,
#  20240428,
#  20240427,
#  20240426,
#  20110511,
#  20110510,
#  20110509,
#  20110508,
#  20110507,
#  20110506,
#  20110505,
#  20110504,
#  20110503,
#  20110502,
#  20110501,
#  20110430,
#  20110429,
#  20110428,
#  20110427,
#  20110426,
#  20110425,
#  20110424,
#  20110423,
#  20110422,
#  20110421,
#  20110420,
#  20110419,
#  20110418,
#  20110417,
#  20110416,
#  20110415,
#  20110414,
#  20110413,
#  20110412,
#  20110411,
#  20110410,
#  20110409,
#  20110408,
#  20110407,
#  20110406,
#  20110405,
#  20110404,
#  20110403,
#  20110402,
#  20110401,
#  20110331,
#  20110330,
#  20110329,
#  20110328,
#  20110327,
#  20110326,
#  20110325,
#  20110324,
#  20110323,
#  20110322,
#  20110321,
#  20110320,
#  20110319,
#  20110318,
#  20110317,
#  20110316,
#  20110315,
#  20110314,
#  20110313,
#  20110312,
#  20110311,
#  20110310,
#  20110309,
#  20110308,
#  20110307,
#  20110306,
#  20110305,
#  20110304,
#  20110303,
#  20110302,
#  20110301,
#  20110228,
#  20110227,
#  20110226,
#  20110225,
#  20110224,
#  20110223,
#  20110222,
#  20110221,
#  20110220,
#  20110219,
#  20110218,
#  20110217,
#  20110216,
#  20110215,
#  20110214,
#  20110213,
#  20110212,
#  20110211,
#  20110210,
#  20110209,
#  20110208,
#  20110207,
#  20110206,
#  20110205,
#  20110204,
#  20110203,
#  20110202,
#  20110201,
#  20110131,
#  20110130,
#  20110129,
#  20110128,
#  20110127,
#  20110126,
#  20110125,
#  20110124,
#  20110123,
#  20110122,
#  20110121,
#  20110120,
#  20110119,
#  20110118,
#  20110117,
#  20110116,
#  20110115,
#  20110114,
#  20110113,
#  20110112,
#  20110111,
#  20110110,
#  20110109,
#  20110108,
#  20110107,
#  20110106,
#  20110105,
#  20110104,
#  ...]

# %%
for day in missing_game_days:
    if day < 20040301:
        try:
            add_game_data_to_db(day)
            days_already_tried_adding.append(day)
            print(" successfully added game data for " + str(day) + " to the database")
        except:
            print(" failed to add game data for " + str(day) + " to the database")
# Out:
# connecting to postgresql database...
#  successfully added game data for 20220414 to the database
# connecting to postgresql database...
#  successfully added game data for 20220411 to the database
# connecting to postgresql database...
#  successfully added game data for 20220404 to the database
# connecting to postgresql database...
#  successfully added game data for 20220223 to the database
# connecting to postgresql database...
#  successfully added game data for 20220222 to the database
# connecting to postgresql database...
#  successfully added game data for 20220221 to the database
# connecting to postgresql database...
#  successfully added game data for 20220220 to the database
# connecting to postgresql database...
#  successfully added game data for 20220219 to the database
# connecting to postgresql database...
#  successfully added game data for 20220218 to the database
# connecting to postgresql database...
#  successfully added game data for 20211224 to the database
# connecting to postgresql database...
#  successfully added game data for 20211125 to the database
# connecting to postgresql database...
#  successfully added game data for 20210720 to the database
# connecting to postgresql database...
#  successfully added game data for 20210719 to the database
# connecting to postgresql database...
#  successfully added game data for 20210718 to the database
# connecting to postgresql database...
#  successfully added game data for 20210717 to the database
# connecting to postgresql database...
#  successfully added game data for 20210716 to the database
# connecting to postgresql database...
#  successfully added game data for 20210715 to the database
# connecting to postgresql database...
#  successfully added game data for 20210714 to the database
# connecting to postgresql database...
#  successfully added game data for 20210713 to the database
# connecting to postgresql database...
#  successfully added game data for 20210712 to the database
# connecting to postgresql database...
#  successfully added game data for 20210711 to the database
# connecting to postgresql database...
#  successfully added game data for 20210710 to the database
# connecting to postgresql database...
#  successfully added game data for 20210709 to the database
# connecting to postgresql database...
#  successfully added game data for 20210708 to the database
# connecting to postgresql database...
#  successfully added game data for 20210707 to the database
# connecting to postgresql database...
#  successfully added game data for 20210706 to the database
# connecting to postgresql database...
#  successfully added game data for 20210705 to the database
# connecting to postgresql database...
#  successfully added game data for 20210704 to the database
# connecting to postgresql database...
#  successfully added game data for 20210703 to the database
# connecting to postgresql database...
#  successfully added game data for 20210702 to the database
# connecting to postgresql database...
#  successfully added game data for 20210701 to the database
# connecting to postgresql database...
#  successfully added game data for 20210621 to the database
# connecting to postgresql database...
#  successfully added game data for 20210517 to the database
# connecting to postgresql database...
#  successfully added game data for 20210309 to the database
# connecting to postgresql database...
#  successfully added game data for 20210308 to the database
# connecting to postgresql database...
#  successfully added game data for 20210307 to the database
# connecting to postgresql database...
#  successfully added game data for 20210306 to the database
# connecting to postgresql database...
#  successfully added game data for 20210305 to the database
# connecting to postgresql database...
#  successfully added game data for 20201224 to the database
# connecting to postgresql database...
#  successfully added game data for 20201011 to the database
# connecting to postgresql database...
#  successfully added game data for 20201010 to the database
# connecting to postgresql database...
#  successfully added game data for 20201009 to the database
# connecting to postgresql database...
#  successfully added game data for 20201008 to the database
# connecting to postgresql database...
#  successfully added game data for 20201007 to the database
# connecting to postgresql database...
#  successfully added game data for 20201006 to the database
# connecting to postgresql database...
#  successfully added game data for 20201005 to the database
# connecting to postgresql database...
#  successfully added game data for 20201004 to the database
# connecting to postgresql database...
#  successfully added game data for 20201003 to the database
# connecting to postgresql database...
#  successfully added game data for 20201002 to the database
# connecting to postgresql database...
#  successfully added game data for 20201001 to the database
# connecting to postgresql database...
#  successfully added game data for 20200930 to the database
# connecting to postgresql database...
#  successfully added game data for 20200929 to the database
# connecting to postgresql database...
#  successfully added game data for 20200928 to the database
# connecting to postgresql database...
#  successfully added game data for 20200927 to the database
# connecting to postgresql database...
#  successfully added game data for 20200926 to the database
# connecting to postgresql database...
#  successfully added game data for 20200925 to the database
# connecting to postgresql database...
#  successfully added game data for 20200924 to the database
# connecting to postgresql database...
#  successfully added game data for 20200923 to the database
# connecting to postgresql database...
#  successfully added game data for 20200922 to the database
# connecting to postgresql database...
#  successfully added game data for 20200921 to the database
# connecting to postgresql database...
#  successfully added game data for 20200920 to the database
# connecting to postgresql database...
#  successfully added game data for 20200919 to the database
# connecting to postgresql database...
#  successfully added game data for 20200918 to the database
# connecting to postgresql database...
#  successfully added game data for 20200917 to the database
# connecting to postgresql database...
#  successfully added game data for 20200916 to the database
# connecting to postgresql database...
#  successfully added game data for 20200915 to the database
# connecting to postgresql database...
#  successfully added game data for 20200914 to the database
# connecting to postgresql database...
#  successfully added game data for 20200913 to the database
# connecting to postgresql database...
#  successfully added game data for 20200912 to the database
# connecting to postgresql database...
#  successfully added game data for 20200911 to the database
# connecting to postgresql database...
#  successfully added game data for 20200910 to the database
# connecting to postgresql database...
#  successfully added game data for 20200909 to the database
# connecting to postgresql database...
#  successfully added game data for 20200908 to the database
# connecting to postgresql database...
#  successfully added game data for 20200907 to the database
# connecting to postgresql database...
#  successfully added game data for 20200906 to the database
# connecting to postgresql database...
#  successfully added game data for 20200905 to the database
# connecting to postgresql database...
#  successfully added game data for 20200904 to the database
# connecting to postgresql database...
#  successfully added game data for 20200903 to the database
# connecting to postgresql database...
#  successfully added game data for 20200902 to the database
# connecting to postgresql database...
#  successfully added game data for 20200901 to the database
# connecting to postgresql database...
#  successfully added game data for 20200831 to the database
# connecting to postgresql database...
#  successfully added game data for 20200830 to the database
# connecting to postgresql database...
#  successfully added game data for 20200829 to the database
# connecting to postgresql database...
#  successfully added game data for 20200828 to the database
# connecting to postgresql database...
#  successfully added game data for 20200827 to the database
# connecting to postgresql database...
#  successfully added game data for 20200826 to the database
# connecting to postgresql database...
#  successfully added game data for 20200825 to the database
# connecting to postgresql database...
#  successfully added game data for 20200824 to the database
# connecting to postgresql database...
#  successfully added game data for 20200823 to the database
# connecting to postgresql database...
#  successfully added game data for 20200822 to the database
# connecting to postgresql database...
#  successfully added game data for 20200821 to the database
# connecting to postgresql database...
#  successfully added game data for 20200820 to the database
# connecting to postgresql database...
#  successfully added game data for 20200819 to the database
# connecting to postgresql database...
#  successfully added game data for 20200818 to the database
# connecting to postgresql database...
#  successfully added game data for 20200817 to the database
# connecting to postgresql database...
#  successfully added game data for 20200816 to the database
# connecting to postgresql database...
#  successfully added game data for 20200815 to the database
# connecting to postgresql database...
#  successfully added game data for 20200814 to the database
# connecting to postgresql database...
#  successfully added game data for 20200813 to the database
# connecting to postgresql database...
#  successfully added game data for 20200812 to the database
# connecting to postgresql database...
#  successfully added game data for 20200811 to the database
# connecting to postgresql database...
#  successfully added game data for 20200810 to the database
# connecting to postgresql database...
#  successfully added game data for 20200809 to the database
# connecting to postgresql database...
#  successfully added game data for 20200808 to the database
# connecting to postgresql database...
#  successfully added game data for 20200807 to the database
# connecting to postgresql database...
#  successfully added game data for 20200806 to the database
# connecting to postgresql database...
#  successfully added game data for 20200805 to the database
# connecting to postgresql database...
#  successfully added game data for 20200804 to the database
# connecting to postgresql database...
#  successfully added game data for 20200803 to the database
# connecting to postgresql database...
#  successfully added game data for 20200802 to the database
# connecting to postgresql database...
#  successfully added game data for 20200801 to the database
# connecting to postgresql database...
#  successfully added game data for 20200731 to the database
# connecting to postgresql database...
#  successfully added game data for 20200730 to the database
# connecting to postgresql database...
#  successfully added game data for 20200729 to the database
# connecting to postgresql database...
#  successfully added game data for 20200728 to the database
# connecting to postgresql database...
#  successfully added game data for 20200727 to the database
# connecting to postgresql database...
#  successfully added game data for 20200726 to the database
# connecting to postgresql database...
#  successfully added game data for 20200725 to the database
# connecting to postgresql database...
#  successfully added game data for 20200724 to the database
# connecting to postgresql database...
#  successfully added game data for 20200723 to the database
# connecting to postgresql database...
#  successfully added game data for 20200722 to the database
# connecting to postgresql database...
#  successfully added game data for 20200721 to the database
# connecting to postgresql database...
#  successfully added game data for 20200720 to the database
# connecting to postgresql database...
#  successfully added game data for 20200719 to the database
# connecting to postgresql database...
#  successfully added game data for 20200718 to the database
# connecting to postgresql database...
#  successfully added game data for 20200717 to the database
# connecting to postgresql database...
#  successfully added game data for 20200716 to the database
# connecting to postgresql database...
#  successfully added game data for 20200715 to the database
# connecting to postgresql database...
#  successfully added game data for 20200714 to the database
# connecting to postgresql database...
#  successfully added game data for 20200713 to the database
# connecting to postgresql database...
#  successfully added game data for 20200712 to the database
# connecting to postgresql database...
#  successfully added game data for 20200711 to the database
# connecting to postgresql database...
#  successfully added game data for 20200710 to the database
# connecting to postgresql database...
#  successfully added game data for 20200709 to the database
# connecting to postgresql database...
#  successfully added game data for 20200708 to the database
# connecting to postgresql database...
#  successfully added game data for 20200707 to the database
# connecting to postgresql database...
#  successfully added game data for 20200706 to the database
# connecting to postgresql database...
#  successfully added game data for 20200705 to the database
# connecting to postgresql database...
#  successfully added game data for 20200704 to the database
# connecting to postgresql database...
#  successfully added game data for 20200703 to the database
# connecting to postgresql database...
#  successfully added game data for 20200702 to the database
# connecting to postgresql database...
#  successfully added game data for 20200701 to the database
# connecting to postgresql database...
#  successfully added game data for 20200630 to the database
# connecting to postgresql database...
#  successfully added game data for 20200629 to the database
# connecting to postgresql database...
#  successfully added game data for 20200628 to the database
# connecting to postgresql database...
#  successfully added game data for 20200627 to the database
# connecting to postgresql database...
#  successfully added game data for 20200626 to the database
# connecting to postgresql database...
#  successfully added game data for 20200625 to the database
# connecting to postgresql database...
#  successfully added game data for 20200624 to the database
# connecting to postgresql database...
#  successfully added game data for 20200623 to the database
# connecting to postgresql database...
#  successfully added game data for 20200622 to the database
# connecting to postgresql database...
#  successfully added game data for 20200621 to the database
# connecting to postgresql database...
#  successfully added game data for 20200620 to the database
# connecting to postgresql database...
#  successfully added game data for 20200619 to the database
# connecting to postgresql database...
#  successfully added game data for 20200618 to the database
# connecting to postgresql database...
#  successfully added game data for 20200617 to the database
# connecting to postgresql database...
#  successfully added game data for 20200616 to the database
# connecting to postgresql database...
#  successfully added game data for 20200615 to the database
# connecting to postgresql database...
#  successfully added game data for 20200614 to the database
# connecting to postgresql database...
#  successfully added game data for 20200613 to the database
# connecting to postgresql database...
#  successfully added game data for 20200612 to the database
# connecting to postgresql database...
#  successfully added game data for 20200611 to the database
# connecting to postgresql database...
#  successfully added game data for 20200610 to the database
# connecting to postgresql database...
#  successfully added game data for 20200609 to the database
# connecting to postgresql database...
#  successfully added game data for 20200608 to the database
# connecting to postgresql database...
#  successfully added game data for 20200607 to the database
# connecting to postgresql database...
#  successfully added game data for 20200606 to the database
# connecting to postgresql database...
#  successfully added game data for 20200605 to the database
# connecting to postgresql database...
#  successfully added game data for 20200604 to the database
# connecting to postgresql database...
#  successfully added game data for 20200603 to the database
# connecting to postgresql database...
#  successfully added game data for 20200602 to the database
# connecting to postgresql database...
#  successfully added game data for 20200601 to the database
# connecting to postgresql database...
#  successfully added game data for 20200531 to the database
# connecting to postgresql database...
#  successfully added game data for 20200530 to the database
# connecting to postgresql database...
#  successfully added game data for 20200529 to the database
# connecting to postgresql database...
#  successfully added game data for 20200528 to the database
# connecting to postgresql database...
#  successfully added game data for 20200527 to the database
# connecting to postgresql database...
#  successfully added game data for 20200526 to the database
# connecting to postgresql database...
#  successfully added game data for 20200525 to the database
# connecting to postgresql database...
#  successfully added game data for 20200524 to the database
# connecting to postgresql database...
#  successfully added game data for 20200523 to the database
# connecting to postgresql database...
#  successfully added game data for 20200522 to the database
# connecting to postgresql database...
#  successfully added game data for 20200521 to the database
# connecting to postgresql database...
#  successfully added game data for 20200520 to the database
# connecting to postgresql database...
#  successfully added game data for 20200519 to the database
# connecting to postgresql database...
#  successfully added game data for 20200518 to the database
# connecting to postgresql database...
#  successfully added game data for 20200517 to the database
# connecting to postgresql database...
#  successfully added game data for 20200516 to the database
# connecting to postgresql database...
#  successfully added game data for 20200515 to the database
# connecting to postgresql database...
#  successfully added game data for 20200514 to the database
# connecting to postgresql database...
#  successfully added game data for 20200513 to the database
# connecting to postgresql database...
#  successfully added game data for 20200512 to the database
# connecting to postgresql database...
#  successfully added game data for 20200511 to the database
# connecting to postgresql database...
#  successfully added game data for 20200510 to the database
# connecting to postgresql database...
#  successfully added game data for 20200509 to the database
# connecting to postgresql database...
#  successfully added game data for 20200508 to the database
# connecting to postgresql database...
#  successfully added game data for 20200507 to the database
# connecting to postgresql database...
#  successfully added game data for 20200506 to the database
# connecting to postgresql database...
#  successfully added game data for 20200505 to the database
# connecting to postgresql database...
#  successfully added game data for 20200504 to the database
# connecting to postgresql database...
#  successfully added game data for 20200503 to the database
# connecting to postgresql database...
#  successfully added game data for 20200502 to the database
# connecting to postgresql database...
#  successfully added game data for 20200501 to the database
# connecting to postgresql database...
#  successfully added game data for 20200430 to the database
# connecting to postgresql database...
#  successfully added game data for 20200429 to the database
# connecting to postgresql database...
#  successfully added game data for 20200428 to the database
# connecting to postgresql database...
#  successfully added game data for 20200427 to the database
# connecting to postgresql database...
#  successfully added game data for 20200426 to the database
# connecting to postgresql database...
#  successfully added game data for 20200425 to the database
# connecting to postgresql database...
#  successfully added game data for 20200424 to the database
# connecting to postgresql database...
#  successfully added game data for 20200423 to the database
# connecting to postgresql database...
#  successfully added game data for 20200422 to the database
# connecting to postgresql database...
#  successfully added game data for 20200421 to the database
# connecting to postgresql database...
#  failed to add game data for 20200420 to the database
# connecting to postgresql database...
#  successfully added game data for 20200419 to the database
# connecting to postgresql database...
#  successfully added game data for 20200418 to the database
# connecting to postgresql database...
#  successfully added game data for 20200417 to the database
# connecting to postgresql database...
#  successfully added game data for 20200416 to the database
# connecting to postgresql database...
#  successfully added game data for 20200415 to the database
# connecting to postgresql database...
#  successfully added game data for 20200414 to the database
# connecting to postgresql database...
#  successfully added game data for 20200413 to the database
# connecting to postgresql database...
#  successfully added game data for 20200412 to the database
# connecting to postgresql database...
#  successfully added game data for 20200411 to the database
# connecting to postgresql database...
#  successfully added game data for 20200410 to the database
# connecting to postgresql database...
#  successfully added game data for 20200409 to the database
# connecting to postgresql database...
#  successfully added game data for 20200408 to the database
# connecting to postgresql database...
#  successfully added game data for 20200407 to the database
# connecting to postgresql database...
#  successfully added game data for 20200406 to the database
# connecting to postgresql database...
#  successfully added game data for 20200405 to the database
# connecting to postgresql database...
#  successfully added game data for 20200404 to the database
# connecting to postgresql database...
#  successfully added game data for 20200403 to the database
# connecting to postgresql database...
#  successfully added game data for 20200402 to the database
# connecting to postgresql database...
#  successfully added game data for 20200401 to the database
# connecting to postgresql database...
#  successfully added game data for 20200331 to the database
# connecting to postgresql database...
#  successfully added game data for 20200330 to the database
# connecting to postgresql database...
#  successfully added game data for 20200329 to the database
# connecting to postgresql database...
#  successfully added game data for 20200328 to the database
# connecting to postgresql database...
#  successfully added game data for 20200327 to the database
# connecting to postgresql database...
#  successfully added game data for 20200326 to the database
# connecting to postgresql database...
#  successfully added game data for 20200325 to the database
# connecting to postgresql database...
#  successfully added game data for 20200324 to the database
# connecting to postgresql database...
#  successfully added game data for 20200323 to the database
# connecting to postgresql database...
#  successfully added game data for 20200322 to the database
# connecting to postgresql database...
#  successfully added game data for 20200321 to the database
# connecting to postgresql database...
#  successfully added game data for 20200320 to the database
# connecting to postgresql database...
#  successfully added game data for 20200319 to the database
# connecting to postgresql database...
#  successfully added game data for 20200318 to the database
# connecting to postgresql database...
#  successfully added game data for 20200317 to the database
# connecting to postgresql database...
#  successfully added game data for 20200316 to the database
# connecting to postgresql database...
#  successfully added game data for 20200315 to the database
# connecting to postgresql database...
#  successfully added game data for 20200314 to the database
# connecting to postgresql database...
#  successfully added game data for 20200313 to the database
# connecting to postgresql database...
#  successfully added game data for 20200312 to the database
# connecting to postgresql database...
#  successfully added game data for 20200311 to the database
# connecting to postgresql database...
#  successfully added game data for 20200310 to the database
# connecting to postgresql database...
#  successfully added game data for 20200309 to the database
# connecting to postgresql database...
#  successfully added game data for 20200308 to the database
# connecting to postgresql database...
#  successfully added game data for 20200307 to the database
# connecting to postgresql database...
#  successfully added game data for 20200306 to the database
# connecting to postgresql database...
#  successfully added game data for 20200305 to the database
# connecting to postgresql database...
#  successfully added game data for 20200304 to the database
# connecting to postgresql database...
#  successfully added game data for 20200303 to the database
# connecting to postgresql database...
#  successfully added game data for 20200302 to the database
# connecting to postgresql database...
#  successfully added game data for 20200301 to the database
# connecting to postgresql database...
#  successfully added game data for 20200229 to the database
# connecting to postgresql database...
#  successfully added game data for 20200228 to the database
# connecting to postgresql database...
#  successfully added game data for 20200227 to the database
# connecting to postgresql database...
#  successfully added game data for 20200226 to the database
# connecting to postgresql database...
#  successfully added game data for 20200225 to the database
# connecting to postgresql database...
#  successfully added game data for 20200224 to the database
# connecting to postgresql database...
#  successfully added game data for 20200223 to the database
# connecting to postgresql database...
#  successfully added game data for 20200222 to the database
# connecting to postgresql database...
#  successfully added game data for 20200221 to the database
# connecting to postgresql database...
#  successfully added game data for 20200220 to the database
# connecting to postgresql database...
#  successfully added game data for 20200219 to the database
# connecting to postgresql database...
#  successfully added game data for 20200218 to the database
# connecting to postgresql database...
#  successfully added game data for 20200217 to the database
# connecting to postgresql database...
#  successfully added game data for 20200216 to the database
# connecting to postgresql database...
#  successfully added game data for 20200215 to the database
# connecting to postgresql database...
#  successfully added game data for 20200214 to the database
# connecting to postgresql database...
#  successfully added game data for 20200213 to the database
# connecting to postgresql database...
#  successfully added game data for 20200212 to the database
# connecting to postgresql database...
#  successfully added game data for 20200211 to the database
# connecting to postgresql database...
#  successfully added game data for 20200210 to the database
# connecting to postgresql database...
#  successfully added game data for 20200209 to the database
# connecting to postgresql database...
#  successfully added game data for 20200208 to the database
# connecting to postgresql database...
#  successfully added game data for 20200207 to the database
# connecting to postgresql database...
#  successfully added game data for 20200206 to the database
# connecting to postgresql database...
#  successfully added game data for 20200205 to the database
# connecting to postgresql database...
#  successfully added game data for 20200204 to the database
# connecting to postgresql database...
#  successfully added game data for 20200203 to the database
# connecting to postgresql database...
#  successfully added game data for 20200202 to the database
# connecting to postgresql database...
#  successfully added game data for 20200201 to the database
# connecting to postgresql database...
#  successfully added game data for 20200131 to the database
# connecting to postgresql database...
#  successfully added game data for 20200130 to the database
# connecting to postgresql database...
#  successfully added game data for 20200129 to the database
# connecting to postgresql database...
#  successfully added game data for 20200128 to the database
# connecting to postgresql database...
#  successfully added game data for 20200127 to the database
# connecting to postgresql database...
#  successfully added game data for 20200126 to the database
# connecting to postgresql database...
#  successfully added game data for 20200125 to the database
# connecting to postgresql database...
#  successfully added game data for 20200124 to the database
# connecting to postgresql database...
#  successfully added game data for 20200123 to the database
# connecting to postgresql database...
#  successfully added game data for 20200122 to the database
# connecting to postgresql database...
#  successfully added game data for 20200121 to the database
# connecting to postgresql database...
#  successfully added game data for 20200120 to the database
# connecting to postgresql database...
#  successfully added game data for 20200119 to the database
# connecting to postgresql database...
#  successfully added game data for 20200118 to the database
# connecting to postgresql database...
#  successfully added game data for 20200117 to the database
# connecting to postgresql database...
#  successfully added game data for 20200116 to the database
# connecting to postgresql database...
#  successfully added game data for 20200115 to the database
# connecting to postgresql database...
#  successfully added game data for 20200114 to the database
# connecting to postgresql database...
#  successfully added game data for 20200113 to the database
# connecting to postgresql database...
#  successfully added game data for 20200112 to the database
# connecting to postgresql database...
#  successfully added game data for 20200111 to the database
# connecting to postgresql database...
#  successfully added game data for 20200110 to the database
# connecting to postgresql database...
#  successfully added game data for 20200109 to the database
# connecting to postgresql database...
#  successfully added game data for 20200108 to the database
# connecting to postgresql database...
#  successfully added game data for 20200107 to the database
# connecting to postgresql database...
#  successfully added game data for 20200106 to the database
# connecting to postgresql database...
#  successfully added game data for 20200105 to the database
# connecting to postgresql database...
#  successfully added game data for 20200104 to the database
# connecting to postgresql database...
#  successfully added game data for 20200103 to the database
# connecting to postgresql database...
#  successfully added game data for 20200102 to the database
# connecting to postgresql database...
#  successfully added game data for 20200101 to the database
# connecting to postgresql database...
#  successfully added game data for 20191231 to the database
# connecting to postgresql database...
#  successfully added game data for 20191230 to the database
# connecting to postgresql database...
#  successfully added game data for 20191229 to the database
# connecting to postgresql database...
#  successfully added game data for 20191228 to the database
# connecting to postgresql database...
#  successfully added game data for 20191227 to the database
# connecting to postgresql database...
#  successfully added game data for 20191226 to the database
# connecting to postgresql database...
#  successfully added game data for 20191225 to the database
# connecting to postgresql database...
#  successfully added game data for 20191224 to the database
# connecting to postgresql database...
#  successfully added game data for 20191223 to the database
# connecting to postgresql database...
#  successfully added game data for 20191222 to the database
# connecting to postgresql database...
#  failed to add game data for 20191221 to the database
# connecting to postgresql database...
#  successfully added game data for 20191220 to the database
# connecting to postgresql database...
#  successfully added game data for 20191219 to the database
# connecting to postgresql database...
#  successfully added game data for 20191218 to the database
# connecting to postgresql database...
#  successfully added game data for 20191217 to the database
# connecting to postgresql database...
#  successfully added game data for 20191216 to the database
# connecting to postgresql database...
#  successfully added game data for 20191215 to the database
# connecting to postgresql database...
#  successfully added game data for 20191214 to the database
# connecting to postgresql database...
#  successfully added game data for 20191213 to the database
# connecting to postgresql database...
#  successfully added game data for 20191212 to the database
# connecting to postgresql database...
#  successfully added game data for 20191211 to the database
# connecting to postgresql database...
#  successfully added game data for 20191210 to the database
# connecting to postgresql database...
#  successfully added game data for 20191209 to the database
# connecting to postgresql database...
#  successfully added game data for 20191208 to the database
# connecting to postgresql database...
#  successfully added game data for 20191207 to the database
# connecting to postgresql database...
#  successfully added game data for 20191206 to the database
# connecting to postgresql database...
#  successfully added game data for 20191205 to the database
# connecting to postgresql database...
#  successfully added game data for 20191204 to the database
# connecting to postgresql database...
#  successfully added game data for 20191203 to the database
# connecting to postgresql database...
#  successfully added game data for 20191202 to the database
# connecting to postgresql database...
#  successfully added game data for 20191201 to the database
# connecting to postgresql database...
#  successfully added game data for 20191130 to the database
# connecting to postgresql database...
#  successfully added game data for 20191129 to the database
# connecting to postgresql database...
#  successfully added game data for 20191128 to the database
# connecting to postgresql database...
#  successfully added game data for 20191127 to the database
# connecting to postgresql database...
#  successfully added game data for 20191126 to the database
# connecting to postgresql database...
#  successfully added game data for 20191125 to the database
# connecting to postgresql database...
#  successfully added game data for 20191124 to the database
# connecting to postgresql database...
#  successfully added game data for 20191123 to the database
# connecting to postgresql database...
#  successfully added game data for 20191122 to the database
# connecting to postgresql database...
#  successfully added game data for 20191121 to the database
# connecting to postgresql database...
#  successfully added game data for 20191120 to the database
# connecting to postgresql database...
#  successfully added game data for 20191119 to the database
# connecting to postgresql database...
#  successfully added game data for 20191118 to the database
# connecting to postgresql database...
#  successfully added game data for 20191117 to the database
# connecting to postgresql database...
#  successfully added game data for 20191116 to the database
# connecting to postgresql database...
#  successfully added game data for 20191115 to the database
# connecting to postgresql database...
#  successfully added game data for 20191114 to the database
# connecting to postgresql database...
#  successfully added game data for 20191113 to the database
# connecting to postgresql database...
#  successfully added game data for 20191112 to the database
# connecting to postgresql database...
#  successfully added game data for 20191111 to the database
# connecting to postgresql database...
#  successfully added game data for 20191110 to the database
# connecting to postgresql database...
#  successfully added game data for 20191109 to the database
# connecting to postgresql database...
#  successfully added game data for 20191108 to the database
# connecting to postgresql database...
#  successfully added game data for 20191107 to the database
# connecting to postgresql database...
#  successfully added game data for 20191106 to the database
# connecting to postgresql database...
#  successfully added game data for 20191105 to the database
# connecting to postgresql database...
#  successfully added game data for 20191104 to the database
# connecting to postgresql database...
#  successfully added game data for 20191103 to the database
# connecting to postgresql database...
#  successfully added game data for 20191102 to the database
# connecting to postgresql database...
#  successfully added game data for 20191101 to the database
# connecting to postgresql database...
#  successfully added game data for 20191031 to the database
# connecting to postgresql database...
#  successfully added game data for 20191030 to the database
# connecting to postgresql database...
#  successfully added game data for 20191029 to the database
# connecting to postgresql database...
#  successfully added game data for 20191028 to the database
# connecting to postgresql database...
#  successfully added game data for 20191027 to the database
# connecting to postgresql database...
#  successfully added game data for 20191026 to the database
# connecting to postgresql database...
#  successfully added game data for 20191025 to the database
# connecting to postgresql database...
#  successfully added game data for 20191024 to the database
# connecting to postgresql database...
#  successfully added game data for 20191023 to the database
# connecting to postgresql database...
#  successfully added game data for 20191022 to the database
# connecting to postgresql database...
#  successfully added game data for 20190612 to the database
# connecting to postgresql database...
#  successfully added game data for 20190611 to the database
# connecting to postgresql database...
#  successfully added game data for 20190609 to the database
# connecting to postgresql database...
#  successfully added game data for 20190608 to the database
# connecting to postgresql database...
#  successfully added game data for 20190606 to the database
# connecting to postgresql database...
#  successfully added game data for 20190604 to the database
# connecting to postgresql database...
#  successfully added game data for 20190603 to the database
# connecting to postgresql database...
#  successfully added game data for 20190601 to the database
# connecting to postgresql database...
#  successfully added game data for 20190531 to the database
# connecting to postgresql database...
#  successfully added game data for 20190529 to the database
# connecting to postgresql database...
#  successfully added game data for 20190528 to the database
# connecting to postgresql database...
#  successfully added game data for 20190527 to the database
# connecting to postgresql database...
#  successfully added game data for 20190526 to the database
# connecting to postgresql database...
#  successfully added game data for 20190524 to the database
# connecting to postgresql database...
#  successfully added game data for 20190522 to the database
# connecting to postgresql database...
#  successfully added game data for 20190513 to the database
# connecting to postgresql database...
#  successfully added game data for 20190511 to the database
# connecting to postgresql database...
#  successfully added game data for 20190412 to the database
# connecting to postgresql database...
#  successfully added game data for 20190411 to the database
# connecting to postgresql database...
#  successfully added game data for 20190408 to the database
# connecting to postgresql database...
#  successfully added game data for 20190220 to the database
# connecting to postgresql database...
#  successfully added game data for 20190219 to the database
# connecting to postgresql database...
#  successfully added game data for 20190218 to the database
# connecting to postgresql database...
#  successfully added game data for 20190217 to the database
# connecting to postgresql database...
#  successfully added game data for 20190216 to the database
# connecting to postgresql database...
#  successfully added game data for 20190215 to the database
# connecting to postgresql database...
#  successfully added game data for 20181224 to the database
# connecting to postgresql database...
#  successfully added game data for 20181122 to the database
# connecting to postgresql database...
#  successfully added game data for 20180607 to the database
# connecting to postgresql database...
#  successfully added game data for 20180605 to the database
# connecting to postgresql database...
#  successfully added game data for 20180604 to the database
# connecting to postgresql database...
#  successfully added game data for 20180602 to the database
# connecting to postgresql database...
#  successfully added game data for 20180601 to the database
# connecting to postgresql database...
#  successfully added game data for 20180530 to the database
# connecting to postgresql database...
#  successfully added game data for 20180529 to the database
# connecting to postgresql database...
#  successfully added game data for 20180518 to the database
# connecting to postgresql database...
#  successfully added game data for 20180517 to the database
# connecting to postgresql database...
#  successfully added game data for 20180512 to the database
# connecting to postgresql database...
#  successfully added game data for 20180511 to the database
# connecting to postgresql database...
#  successfully added game data for 20180510 to the database
# connecting to postgresql database...
#  successfully added game data for 20180413 to the database
# connecting to postgresql database...
#  successfully added game data for 20180412 to the database
# connecting to postgresql database...
#  successfully added game data for 20180402 to the database
# connecting to postgresql database...
#  successfully added game data for 20180221 to the database
# connecting to postgresql database...
#  successfully added game data for 20180220 to the database
# connecting to postgresql database...
#  successfully added game data for 20180219 to the database
# connecting to postgresql database...
#  successfully added game data for 20180218 to the database
# connecting to postgresql database...
#  successfully added game data for 20180217 to the database
# connecting to postgresql database...
#  successfully added game data for 20180216 to the database
# connecting to postgresql database...
#  successfully added game data for 20171224 to the database
# connecting to postgresql database...
#  successfully added game data for 20171123 to the database
# connecting to postgresql database...
#  successfully added game data for 20170611 to the database
# connecting to postgresql database...
#  successfully added game data for 20170610 to the database
# connecting to postgresql database...
#  successfully added game data for 20170608 to the database
# connecting to postgresql database...
#  successfully added game data for 20170606 to the database
# connecting to postgresql database...
#  successfully added game data for 20170605 to the database
# connecting to postgresql database...
#  successfully added game data for 20170603 to the database
# connecting to postgresql database...
#  successfully added game data for 20170602 to the database
# connecting to postgresql database...
#  failed to add game data for 20170531 to the database
# connecting to postgresql database...
#  successfully added game data for 20170530 to the database
# connecting to postgresql database...
#  successfully added game data for 20170529 to the database
# connecting to postgresql database...
#  successfully added game data for 20170528 to the database
# connecting to postgresql database...
#  successfully added game data for 20170527 to the database
# connecting to postgresql database...
#  successfully added game data for 20170526 to the database
# connecting to postgresql database...
#  successfully added game data for 20170524 to the database
# connecting to postgresql database...
#  successfully added game data for 20170518 to the database
# connecting to postgresql database...
#  successfully added game data for 20170513 to the database
# connecting to postgresql database...
#  successfully added game data for 20170429 to the database
# connecting to postgresql database...
#  successfully added game data for 20170414 to the database
# connecting to postgresql database...
#  successfully added game data for 20170413 to the database
# connecting to postgresql database...
#  successfully added game data for 20170222 to the database
# connecting to postgresql database...
#  successfully added game data for 20170221 to the database
# connecting to postgresql database...
#  successfully added game data for 20170220 to the database
# connecting to postgresql database...
#  successfully added game data for 20170219 to the database
# connecting to postgresql database...
#  successfully added game data for 20170218 to the database
# connecting to postgresql database...
#  successfully added game data for 20170217 to the database
# connecting to postgresql database...
#  successfully added game data for 20161224 to the database
# connecting to postgresql database...
#  successfully added game data for 20161124 to the database
# connecting to postgresql database...
#  successfully added game data for 20160618 to the database
# connecting to postgresql database...
#  successfully added game data for 20160617 to the database
# connecting to postgresql database...
#  successfully added game data for 20160615 to the database
# connecting to postgresql database...
#  successfully added game data for 20160614 to the database
# connecting to postgresql database...
#  successfully added game data for 20160612 to the database
# connecting to postgresql database...
#  successfully added game data for 20160611 to the database
# connecting to postgresql database...
#  successfully added game data for 20160609 to the database
# connecting to postgresql database...
#  successfully added game data for 20160607 to the database
# connecting to postgresql database...
#  successfully added game data for 20160606 to the database
# connecting to postgresql database...
#  successfully added game data for 20160604 to the database
# connecting to postgresql database...
#  successfully added game data for 20160603 to the database
# connecting to postgresql database...
#  successfully added game data for 20160601 to the database
# connecting to postgresql database...
#  successfully added game data for 20160531 to the database
# connecting to postgresql database...
#  successfully added game data for 20160529 to the database
# connecting to postgresql database...
#  successfully added game data for 20160520 to the database
# connecting to postgresql database...
#  successfully added game data for 20160514 to the database
# connecting to postgresql database...
#  successfully added game data for 20160415 to the database
# connecting to postgresql database...
#  successfully added game data for 20160414 to the database
# connecting to postgresql database...
#  successfully added game data for 20160404 to the database
# connecting to postgresql database...
#  successfully added game data for 20160217 to the database
# connecting to postgresql database...
#  successfully added game data for 20160216 to the database
# connecting to postgresql database...
#  successfully added game data for 20160215 to the database
# connecting to postgresql database...
#  successfully added game data for 20160214 to the database
# connecting to postgresql database...
#  successfully added game data for 20160213 to the database
# connecting to postgresql database...
#  successfully added game data for 20160212 to the database
# connecting to postgresql database...
#  successfully added game data for 20151224 to the database
# connecting to postgresql database...
#  successfully added game data for 20151126 to the database
# ...
#  successfully added game data for 20041127 to the database
# connecting to postgresql database...
#  successfully added game data for 20041126 to the database
# connecting to postgresql database...
#  successfully added game data for 20041125 to the database
# connecting to postgresql database...
#  successfully added game data for 20041124 to the database
# connecting to postgresql database...
#  successfully added game data for 20041123 to the database
# connecting to postgresql database...
#  successfully added game data for 20041122 to the database
# connecting to postgresql database...
#  successfully added game data for 20041121 to the database
# connecting to postgresql database...
#  successfully added game data for 20041120 to the database
# connecting to postgresql database...
#  successfully added game data for 20041119 to the database
# connecting to postgresql database...
#  successfully added game data for 20041118 to the database
# connecting to postgresql database...
#  successfully added game data for 20041117 to the database
# connecting to postgresql database...
#  successfully added game data for 20041116 to the database
# connecting to postgresql database...
#  successfully added game data for 20041115 to the database
# connecting to postgresql database...
#  successfully added game data for 20041114 to the database
# connecting to postgresql database...
#  successfully added game data for 20041113 to the database
# connecting to postgresql database...
#  successfully added game data for 20041112 to the database
# connecting to postgresql database...
#  successfully added game data for 20041111 to the database
# connecting to postgresql database...
#  successfully added game data for 20041110 to the database
# connecting to postgresql database...
#  successfully added game data for 20041109 to the database
# connecting to postgresql database...
#  successfully added game data for 20041108 to the database
# connecting to postgresql database...
#  successfully added game data for 20041107 to the database
# connecting to postgresql database...
#  successfully added game data for 20041106 to the database
# connecting to postgresql database...
#  successfully added game data for 20041105 to the database
# connecting to postgresql database...
#  successfully added game data for 20041104 to the database
# connecting to postgresql database...
#  successfully added game data for 20041103 to the database
# connecting to postgresql database...
#  successfully added game data for 20041102 to the database
# connecting to postgresql database...
#  successfully added game data for 20040615 to the database
# connecting to postgresql database...
#  successfully added game data for 20040614 to the database
# connecting to postgresql database...
#  successfully added game data for 20040613 to the database
# connecting to postgresql database...
#  successfully added game data for 20040612 to the database
# connecting to postgresql database...
#  successfully added game data for 20040611 to the database
# connecting to postgresql database...
#  successfully added game data for 20040610 to the database
# connecting to postgresql database...
#  successfully added game data for 20040609 to the database
# connecting to postgresql database...
#  successfully added game data for 20040608 to the database
# connecting to postgresql database...
#  successfully added game data for 20040607 to the database
# connecting to postgresql database...
#  successfully added game data for 20040606 to the database
# connecting to postgresql database...
#  successfully added game data for 20040605 to the database
# connecting to postgresql database...
#  successfully added game data for 20040604 to the database
# connecting to postgresql database...
#  successfully added game data for 20040603 to the database
# connecting to postgresql database...
#  successfully added game data for 20040602 to the database
# connecting to postgresql database...
#  successfully added game data for 20040601 to the database
# connecting to postgresql database...
#  successfully added game data for 20040531 to the database
# connecting to postgresql database...
#  successfully added game data for 20040530 to the database
# connecting to postgresql database...
#  successfully added game data for 20040529 to the database
# connecting to postgresql database...
#  successfully added game data for 20040528 to the database
# connecting to postgresql database...
#  successfully added game data for 20040527 to the database
# connecting to postgresql database...
#  successfully added game data for 20040526 to the database
# connecting to postgresql database...
#  successfully added game data for 20040525 to the database
# connecting to postgresql database...
#  successfully added game data for 20040524 to the database
# connecting to postgresql database...
#  successfully added game data for 20040523 to the database
# connecting to postgresql database...
#  successfully added game data for 20040522 to the database
# connecting to postgresql database...
#  successfully added game data for 20040521 to the database
# connecting to postgresql database...
#  successfully added game data for 20040520 to the database
# connecting to postgresql database...
#  successfully added game data for 20040519 to the database
# connecting to postgresql database...
#  successfully added game data for 20040518 to the database
# connecting to postgresql database...
#  successfully added game data for 20040517 to the database
# connecting to postgresql database...
#  successfully added game data for 20040516 to the database
# connecting to postgresql database...
#  successfully added game data for 20040515 to the database
# connecting to postgresql database...
#  successfully added game data for 20040514 to the database
# connecting to postgresql database...
#  successfully added game data for 20040513 to the database
# connecting to postgresql database...
#  successfully added game data for 20040512 to the database
# connecting to postgresql database...
#  successfully added game data for 20040511 to the database
# connecting to postgresql database...
#  successfully added game data for 20040510 to the database
# connecting to postgresql database...
#  successfully added game data for 20040509 to the database
# connecting to postgresql database...
#  successfully added game data for 20040508 to the database
# connecting to postgresql database...
#  successfully added game data for 20040507 to the database
# connecting to postgresql database...
#  successfully added game data for 20040506 to the database
# connecting to postgresql database...
#  successfully added game data for 20040505 to the database
# connecting to postgresql database...
#  successfully added game data for 20040504 to the database
# connecting to postgresql database...
#  successfully added game data for 20040503 to the database
# connecting to postgresql database...
#  successfully added game data for 20040502 to the database
# connecting to postgresql database...
#  successfully added game data for 20040501 to the database
# connecting to postgresql database...
#  successfully added game data for 20040430 to the database
# connecting to postgresql database...
#  successfully added game data for 20040429 to the database
# connecting to postgresql database...
#  successfully added game data for 20040428 to the database
# connecting to postgresql database...
#  successfully added game data for 20040427 to the database
# connecting to postgresql database...
#  successfully added game data for 20040426 to the database
# connecting to postgresql database...
#  successfully added game data for 20040425 to the database
# connecting to postgresql database...
#  successfully added game data for 20040424 to the database
# connecting to postgresql database...
#  successfully added game data for 20040423 to the database
# connecting to postgresql database...
#  successfully added game data for 20040422 to the database
# connecting to postgresql database...
#  successfully added game data for 20040421 to the database
# connecting to postgresql database...
#  successfully added game data for 20040420 to the database
# connecting to postgresql database...
#  successfully added game data for 20040419 to the database
# connecting to postgresql database...
#  successfully added game data for 20040418 to the database
# connecting to postgresql database...
#  successfully added game data for 20040417 to the database
# connecting to postgresql database...
#  successfully added game data for 20040416 to the database
# connecting to postgresql database...
#  successfully added game data for 20040415 to the database
# connecting to postgresql database...
#  successfully added game data for 20040414 to the database
# connecting to postgresql database...
#  successfully added game data for 20040413 to the database
# connecting to postgresql database...
#  successfully added game data for 20040412 to the database
# connecting to postgresql database...
#  successfully added game data for 20040411 to the database
# connecting to postgresql database...
#  successfully added game data for 20040410 to the database
# connecting to postgresql database...
#  successfully added game data for 20040409 to the database
# connecting to postgresql database...
#  successfully added game data for 20040408 to the database
# connecting to postgresql database...
#  successfully added game data for 20040407 to the database
# connecting to postgresql database...
#  successfully added game data for 20040406 to the database
# connecting to postgresql database...
#  successfully added game data for 20040405 to the database
# connecting to postgresql database...
#  successfully added game data for 20040404 to the database
# connecting to postgresql database...
#  successfully added game data for 20040403 to the database
# connecting to postgresql database...
#  successfully added game data for 20040402 to the database
# connecting to postgresql database...
#  successfully added game data for 20040401 to the database
# connecting to postgresql database...
#  successfully added game data for 20040331 to the database
# connecting to postgresql database...
#  successfully added game data for 20040330 to the database
# connecting to postgresql database...
#  successfully added game data for 20040329 to the database
# connecting to postgresql database...
#  successfully added game data for 20040328 to the database
# connecting to postgresql database...
#  successfully added game data for 20040327 to the database
# connecting to postgresql database...
#  successfully added game data for 20040326 to the database
# connecting to postgresql database...
#  successfully added game data for 20040325 to the database
# connecting to postgresql database...
#  successfully added game data for 20040324 to the database
# connecting to postgresql database...
#  successfully added game data for 20040323 to the database
# connecting to postgresql database...
#  successfully added game data for 20040322 to the database
# connecting to postgresql database...
#  successfully added game data for 20040321 to the database
# connecting to postgresql database...
#  successfully added game data for 20040320 to the database
# connecting to postgresql database...
#  successfully added game data for 20040319 to the database
# connecting to postgresql database...
#  successfully added game data for 20040318 to the database
# connecting to postgresql database...
#  successfully added game data for 20040317 to the database
# connecting to postgresql database...
#  successfully added game data for 20040316 to the database
# connecting to postgresql database...
#  successfully added game data for 20040315 to the database
# connecting to postgresql database...
#  successfully added game data for 20040314 to the database
# connecting to postgresql database...
#  successfully added game data for 20040313 to the database
# connecting to postgresql database...
#  successfully added game data for 20040312 to the database
# connecting to postgresql database...
#  successfully added game data for 20040311 to the database
# connecting to postgresql database...
#  successfully added game data for 20040310 to the database
# connecting to postgresql database...
#  successfully added game data for 20040309 to the database
# connecting to postgresql database...
#  successfully added game data for 20040308 to the database
# connecting to postgresql database...
#  successfully added game data for 20040307 to the database
# connecting to postgresql database...
#  successfully added game data for 20040306 to the database
# connecting to postgresql database...
#  successfully added game data for 20040305 to the database
# connecting to postgresql database...
#  successfully added game data for 20040304 to the database
# connecting to postgresql database...
#  successfully added game data for 20040303 to the database
# connecting to postgresql database...
#  successfully added game data for 20040302 to the database
# connecting to postgresql database...
#  successfully added game data for 20040301 to the database
# connecting to postgresql database...
#  successfully added game data for 20040229 to the database
# connecting to postgresql database...
#  failed to add game data for 20040228 to the database
# connecting to postgresql database...
#  successfully added game data for 20040227 to the database
# connecting to postgresql database...
#  successfully added game data for 20040226 to the database
# connecting to postgresql database...
#  successfully added game data for 20040225 to the database
# connecting to postgresql database...
#  failed to add game data for 20040224 to the database
# connecting to postgresql database...
#  successfully added game data for 20040223 to the database
# connecting to postgresql database...
#  successfully added game data for 20040222 to the database
# connecting to postgresql database...
#  failed to add game data for 20040221 to the database
# connecting to postgresql database...
#  successfully added game data for 20040220 to the database
# connecting to postgresql database...
#  successfully added game data for 20040219 to the database
# connecting to postgresql database...
#  successfully added game data for 20040218 to the database
# connecting to postgresql database...
#  failed to add game data for 20040217 to the database
# connecting to postgresql database...
#  failed to add game data for 20040216 to the database
# connecting to postgresql database...
#  successfully added game data for 20040215 to the database
# connecting to postgresql database...
#  successfully added game data for 20040214 to the database
# connecting to postgresql database...
#  successfully added game data for 20040213 to the database
# connecting to postgresql database...
#  successfully added game data for 20040212 to the database
# connecting to postgresql database...
#  successfully added game data for 20040211 to the database
# connecting to postgresql database...
#  successfully added game data for 20040210 to the database
# connecting to postgresql database...
#  successfully added game data for 20040209 to the database
# connecting to postgresql database...
#  successfully added game data for 20040208 to the database
# connecting to postgresql database...
#  failed to add game data for 20040207 to the database
# connecting to postgresql database...
#  successfully added game data for 20040206 to the database
# connecting to postgresql database...
#  failed to add game data for 20040205 to the database
# connecting to postgresql database...
#  successfully added game data for 20040204 to the database
# connecting to postgresql database...
#  successfully added game data for 20040203 to the database
# connecting to postgresql database...
#  successfully added game data for 20040202 to the database
# connecting to postgresql database...
#  failed to add game data for 20040201 to the database
# connecting to postgresql database...
#  failed to add game data for 20040131 to the database
# connecting to postgresql database...
#  failed to add game data for 20040130 to the database
# connecting to postgresql database...
#  successfully added game data for 20040129 to the database
# connecting to postgresql database...
#  successfully added game data for 20040128 to the database
# connecting to postgresql database...
#  successfully added game data for 20040127 to the database
# connecting to postgresql database...

# %%
get_game_results('20240923')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_game_results('20240923')
#
# NameError: name 'get_game_results' is not defined

# %%
#todo

#create a list of all valid days in format yyyy/mm/dd

#create a table of playoff start and end dates (do this for the regular season too if needed)

#look into parsing additional (more granular) game data

# %%
def copy_from_stringio(conn, df, table):
    """
    Here we are going save the dataframe in memory 
    and use copy_from() to copy it to the table
    """
    # save dataframe to an in memory buffer
    buffer = io.StringIO()
    df.to_csv(buffer, index_label='id', header=False)
    buffer.seek(0)
    
    cursor = conn.cursor()
    try:
        cursor.copy_from(buffer, table, sep=",")
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print("copy_from_stringio() done")
    cursor.close()

# %%
copy_from_stringio(connect(), final_df, 'game_results')
# Out:
# connecting to postgresql database...
# copy_from_file() done
# database connection terminated
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 copy_from_stringio(connect(), final_df, 'game_results')
#
# Cell In[33], line 11, in copy_from_stringio(conn, df, table)
#       8 df.to_csv(buffer, index_label='id', header=False)
#       9 buffer.seek(0)
# ---> 11 cursor = conn.cursor()
#      12 try:
#      13     cursor.copy_from(buffer, table, sep=",")
#
# AttributeError: 'NoneType' object has no attribute 'cursor'
